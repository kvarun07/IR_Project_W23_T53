# %%
# !pip install youtube_transcript_api
# !pip install transformers
# !pip3 install git+https://github.com/ernie-mlg/rpunct.git
import requests
import json
from youtube_transcript_api import YouTubeTranscriptApi
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: youtube_transcript_api in /usr/local/lib/python3.9/dist-packages (0.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from youtube_transcript_api) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (2.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (4.26.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.49.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/ernie-mlg/rpunct.git
#   Cloning https://github.com/ernie-mlg/rpunct.git to /tmp/pip-req-build-3iu_o1o4
#   Running command git clone --filter=blob:none --quiet https://github.com/ernie-mlg/rpunct.git /tmp/pip-req-build-3iu_o1o4
#   Resolved https://github.com/ernie-mlg/rpunct.git to commit 4c378cf570f05aa58c7d3dbb896b51ca2d95fde6
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: langdetect==1.0.9 in /usr/local/lib/python3.9/dist-packages (from rpunct==1.0.2) (1.0.9)
# Requirement already satisfied: pandas==1.2.4 in /usr/local/lib/python3.9/dist-packages (from rpunct==1.0.2) (1.2.4)
# Requirement already satisfied: simpletransformers==0.61.4 in /usr/local/lib/python3.9/dist-packages (from rpunct==1.0.2) (0.61.4)
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.9/dist-packages (from rpunct==1.0.2) (1.16.0)
# Requirement already satisfied: torch==1.8.1 in /usr/local/lib/python3.9/dist-packages (from rpunct==1.0.2) (1.8.1)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.9/dist-packages (from rpunct==1.0.2) (7.1.2)
# Requirement already satisfied: tqdm==4.49.0 in /usr/local/lib/python3.9/dist-packages (from rpunct==1.0.2) (4.49.0)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.9/dist-packages (from pandas==1.2.4->rpunct==1.0.2) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/dist-packages (from pandas==1.2.4->rpunct==1.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas==1.2.4->rpunct==1.0.2) (2022.7.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (0.1.97)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (1.2.1)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (1.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (2.25.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (0.13.11)
# Requirement already satisfied: tensorboardx in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (2.6)
# Requirement already satisfied: datasets in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (1.2.1)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (0.13.2)
# Requirement already satisfied: transformers>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (4.26.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (2022.6.2)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (1.20.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (1.10.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch==1.8.1->rpunct==1.0.2) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers>=4.2.0->simpletransformers==0.61.4->rpunct==1.0.2) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.2.0->simpletransformers==0.61.4->rpunct==1.0.2) (0.13.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.2.0->simpletransformers==0.61.4->rpunct==1.0.2) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.2.0->simpletransformers==0.61.4->rpunct==1.0.2) (6.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.9/dist-packages (from datasets->simpletransformers==0.61.4->rpunct==1.0.2) (0.3.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from datasets->simpletransformers==0.61.4->rpunct==1.0.2) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.9/dist-packages (from datasets->simpletransformers==0.61.4->rpunct==1.0.2) (0.70.14)
# Requirement already satisfied: pyarrow>=0.17.1 in /usr/local/lib/python3.9/dist-packages (from datasets->simpletransformers==0.61.4->rpunct==1.0.2) (9.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers==0.61.4->rpunct==1.0.2) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers==0.61.4->rpunct==1.0.2) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers==0.61.4->rpunct==1.0.2) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers==0.61.4->rpunct==1.0.2) (2.10)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->simpletransformers==0.61.4->rpunct==1.0.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->simpletransformers==0.61.4->rpunct==1.0.2) (3.1.0)
# Requirement already satisfied: gitpython!=3.1.19 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (3.1.31)
# Requirement already satisfied: altair<5,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (4.2.2)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (2.3.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (13.3.2)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (6.2)
# Requirement already satisfied: pympler>=0.9 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (1.0.1)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (5.3.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.8.0)
# Requirement already satisfied: blinker>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (1.5)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (4.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (8.4.0)
# Requirement already satisfied: validators>=0.2 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.20.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (6.0.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (3.19.6)
# Requirement already satisfied: semver in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (2.13.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.10.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from wandb->simpletransformers==0.61.4->rpunct==1.0.2) (57.4.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from wandb->simpletransformers==0.61.4->rpunct==1.0.2) (0.4.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb->simpletransformers==0.61.4->rpunct==1.0.2) (5.4.8)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb->simpletransformers==0.61.4->rpunct==1.0.2) (1.4.4)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.9/dist-packages (from wandb->simpletransformers==0.61.4->rpunct==1.0.2) (1.3.2)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.9/dist-packages (from wandb->simpletransformers==0.61.4->rpunct==1.0.2) (0.1.2)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb->simpletransformers==0.61.4->rpunct==1.0.2) (1.16.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.12.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (3.1.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (4.3.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from gitpython!=3.1.19->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=1.4->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (3.15.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.11.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.11.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (2.14.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.9/dist-packages (from tzlocal>=1.1->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from validators>=0.2->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (4.4.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (2.1.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.1.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.9/dist-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (2022.7)

# %%
checkpoint = "sshleifer/distilbart-cnn-12-6"

tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading (…)okenizer_config.json', max=26.0, style=Pro…
# HBox(children=(FloatProgress(value=0.0, description='Downloading (…)lve/main/config.json', max=1802.0, style=P…
# HBox(children=(FloatProgress(value=0.0, description='Downloading (…)olve/main/vocab.json', max=898822.0, style…
# HBox(children=(FloatProgress(value=0.0, description='Downloading (…)olve/main/merges.txt', max=456318.0, style…
# HBox(children=(FloatProgress(value=0.0, description='Downloading pytorch_model.bin', max=1222317369.0, style=P…

# %%
from rpunct import RestorePuncts
# The default language is 'english'
rpunct = RestorePuncts(use_cuda=False)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading (…)lve/main/config.json', max=1246.0, style=P…
# HBox(children=(FloatProgress(value=0.0, description='Downloading pytorch_model.bin', max=435701303.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Downloading (…)solve/main/vocab.txt', max=231508.0, style…
# HBox(children=(FloatProgress(value=0.0, description='Downloading (…)cial_tokens_map.json', max=112.0, style=Pr…
# HBox(children=(FloatProgress(value=0.0, description='Downloading (…)okenizer_config.json', max=530.0, style=Pr…

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# %cd "/content/gdrive/MyDrive/IR_Project_W23"
# Out:
# Mounted at /content/gdrive/
# /content/gdrive/.shortcut-targets-by-id/185mvSLpCVGSaXntfPSeAocQRS6XVVq-_/IR_Project_W23

# %%
def fetch_most_replayed(video_id: str):
  r = requests.get(f'https://yt.lemnoslife.com/videos?part=mostReplayed&id={video_id}')
  if r.status_code != 200:
    raise Exception(f'Error while fetching most replayed for id: {video_id}')
  return json.loads(r.text)['items'][0]['mostReplayed']['heatMarkers']

# %%
fetch_most_replayed('YieuqbIqUps')
# Out:
# [{'heatMarkerRenderer': {'timeRangeStartMillis': 0,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 1}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 2060,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.4254768856939025}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 4120,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.3844264537181312}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 6180,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.3299730038315575}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 8240,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.2926660463058963}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 10300,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.33168912891722424}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 12360,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.33937812522396466}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 14420,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.32314734353015806}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 16480,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.3898350464527254}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 18540,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.3836757862291644}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 20600,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.36659001967883426}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 22660,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.37044907834813845}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 24720,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.33208076899970046}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 26780,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.2692229317219072}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 28840,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.19856893705965914}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 30900,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.17579769399583717}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 32960,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.14911336176971499}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 35020,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.1206053114242384}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 37080,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.12096678658124449}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 39140,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.10671533514618056}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 41200,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.10352595222084585}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 43260,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.08275927284387466}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 45320,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06420453201727867}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 47380,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06710486440380051}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 49440,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.058916311013916214}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 51500,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.04900484722995094}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 53560,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.055536363511685435}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 55620,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.04785499842714031}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 57680,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.03943347678231244}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 59740,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05785465322232497}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 61800,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.04937382762199346}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 63860,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.04629673525155622}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 65920,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.054880546355193294}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 67980,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05043714124481576}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 70040,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05624154963629487}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 72100,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.03632038808076526}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 74160,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.03904286259527284}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 76220,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.03530325775075701}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 78280,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.053647204062373145}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 80340,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05257930090733432}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 82400,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.09815612753485714}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 84460,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.12540639407868992}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 86520,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.13230174327711822}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 88580,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.13761512571592652}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 90640,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.19527728855764104}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 92700,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.2315816042765657}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 94760,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.24929478687814224}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 96820,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.4560522413313545}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 98880,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.47152202458916576}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 100940,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.5158605774265064}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 103000,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.5362699932172114}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 105060,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.6000278467617467}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 107120,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.4759973044507412}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 109180,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.319999104411282}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 111240,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.24156864235769634}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 113300,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.2113756397492942}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 115360,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.14600248684253106}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 117420,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.09514154279339232}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 119480,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.09377375420387653}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 121540,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.08052195688006696}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 123600,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06807989702457566}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 125660,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.08168381045930274}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 127720,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.0768678253237717}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 129780,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.09591103636352968}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 131840,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.0886571637072463}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 133900,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.07439237563150614}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 135960,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06680712075102457}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 138020,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.07767295526170791}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 140080,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06580077132218376}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 142140,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.07173402858087093}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 144200,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06684479091153113}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 146260,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05549754146858336}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 148320,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05811949622846641}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 150380,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05033658549386012}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 152440,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.04124056459669405}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 154500,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.056937754676292376}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 156560,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05746936649228964}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 158620,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.054133172530523}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 160680,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.09344269594665833}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 162740,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.10168229213405652}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 164800,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.11103874648680308}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 166860,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.15001247812817925}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 168920,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.15239377941642676}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 170980,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.14485438386177926}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 173040,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.12845719112925133}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 175100,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.08840234567931898}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 177160,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05666702627001446}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 179220,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.056597085398667826}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 181280,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05848460701491461}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 183340,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.055108943076085916}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 185400,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.04443082943214096}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 187460,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.0631058699973064}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 189520,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.07586572346200186}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 191580,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.07970714392906217}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 193640,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.08331430027325895}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 195700,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.09349334278453003}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 197760,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.08354701655388476}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 199820,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06520769577081625}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 201880,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.032283741511930135}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 203940,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0}}]

# %%
def fetch_captions(video_id: str, languages=['en']):
  return YouTubeTranscriptApi.get_transcript(video_id, languages=languages)

# %%
fetch_captions('YieuqbIqUps')
# Out:
# [{'text': 'sugar is okay for you know yes thank you',
#   'start': 0.16,
#   'duration': 6.8},
#  {'text': 'how are you miss kulkarni how i am i am',
#   'start': 3.28,
#   'duration': 5.6},
#  {'text': 'worried like all other mothers', 'start': 6.96, 'duration': 6.0},
#  {'text': 'everywhere all the time we are worried',
#   'start': 8.88,
#   'duration': 8.08},
#  {'text': 'your i am fine is my', 'start': 12.96, 'duration': 4.0},
#  {'text': 'ass toy means toy gun', 'start': 29.119, 'duration': 5.28},
#  {'text': 'it is not making any why we are doing do',
#   'start': 32.48,
#   'duration': 3.919},
#  {'text': 'you have to stop this', 'start': 34.399, 'duration': 4.641},
#  {'text': 'see last year my papa gave pratibha',
#   'start': 36.399,
#   'duration': 4.16},
#  {'text': 'kitchen set', 'start': 39.04, 'duration': 4.08},
#  {'text': 'my husband got so upset just because',
#   'start': 40.559,
#   'duration': 4.401},
#  {'text': "she's girl you are giving her kitchen",
#   'start': 43.12,
#   'duration': 2.72},
#  {'text': 'set', 'start': 44.96, 'duration': 3.36},
#  {'text': 'name but i understand but what', 'start': 45.84, 'duration': 5.199},
#  {'text': "prativha's papa has given pratibha",
#   'start': 48.32,
#   'duration': 5.28},
#  {'text': 'gun did you ask him why he got the gun i',
#   'start': 51.039,
#   'duration': 4.481},
#  {'text': "asked him he's telling no one day",
#   'start': 53.6,
#   'duration': 5.439},
#  {'text': 'pratibha is going to become soldier huh',
#   'start': 55.52,
#   'duration': 5.12},
#  {'text': 'that is why now she has to play with',
#   'start': 59.039,
#   'duration': 2.721},
#  {'text': 'tygan', 'start': 60.64, 'duration': 3.36},
#  {'text': 'that means children who are one day',
#   'start': 61.76,
#   'duration': 4.399},
#  {'text': 'going to become charter accountant are',
#   'start': 64.0,
#   'duration': 5.6},
#  {'text': 'now playing with toy calculator',
#   'start': 66.159,
#   'duration': 5.201},
#  {'text': 'so have you asked prativa if she wants',
#   'start': 69.6,
#   'duration': 4.4},
#  {'text': 'to be a soldier that day she got the toy',
#   'start': 71.36,
#   'duration': 5.52},
#  {'text': 'gun pratibha decided she is going to be',
#   'start': 74.0,
#   'duration': 5.84},
#  {'text': 'shikari shambo shikari shambhu you know',
#   'start': 76.88,
#   'duration': 4.4},
#  {'text': 'comics', 'start': 79.84, 'duration': 3.279},
#  {'text': 'both are same shikhari shampoo and my',
#   'start': 81.28,
#   'duration': 2.879},
#  {'text': 'protiba', 'start': 83.119, 'duration': 4.081},
#  {'text': 'lazy liars telling tall stories all the',
#   'start': 84.159,
#   'duration': 5.761},
#  {'text': 'time and now she also has gun she curry',
#   'start': 87.2,
#   'duration': 5.44},
#  {'text': 'shambo soldier whatever', 'start': 89.92, 'duration': 4.72},
#  {'text': 'summer holidays are on the corner what',
#   'start': 92.64,
#   'duration': 3.6},
#  {'text': 'holiday plans', 'start': 94.64, 'duration': 4.12},
#  {'text': 'yes summer holidays', 'start': 96.24, 'duration': 5.639},
#  {'text': '[Music]', 'start': 98.76, 'duration': 3.119},
#  {'text': "and come back that's all sum up the",
#   'start': 112.479,
#   'duration': 4.0},
#  {'text': 'summer holidays are you not enrolling',
#   'start': 114.64,
#   'duration': 4.079},
#  {'text': 'pratibha in any hobby classes coding is',
#   'start': 116.479,
#   'duration': 4.161},
#  {'text': 'very popular these days', 'start': 118.719, 'duration': 2.801},
#  {'text': 'oh', 'start': 120.64, 'duration': 2.88},
#  {'text': 'computer coding', 'start': 121.52, 'duration': 3.599},
#  {'text': 'programmer', 'start': 123.52, 'duration': 4.08},
#  {'text': 'means then they should have mini mbbs',
#   'start': 125.119,
#   'duration': 6.641},
#  {'text': 'and junior is officer course also no',
#   'start': 127.6,
#   'duration': 5.68},
#  {'text': 'code audio', 'start': 131.76, 'duration': 3.6},
#  {'text': 'maishikari shambu for last one year has',
#   'start': 133.28,
#   'duration': 4.4},
#  {'text': 'not been able to decode multiplication',
#   'start': 135.36,
#   'duration': 3.599},
#  {'text': 'and division', 'start': 137.68, 'duration': 5.52},
#  {'text': 'that the teacher is asking pratibha',
#   'start': 138.959,
#   'duration': 4.241},
#  {'text': 'teacher has not asked what do you want',
#   'start': 148.48,
#   'duration': 3.44},
#  {'text': 'to have nasta', 'start': 150.319, 'duration': 4.481},
#  {'text': 'teacher is asking multiplication tables',
#   'start': 151.92,
#   'duration': 5.92},
#  {'text': 'but my pratibha knows only one table',
#   'start': 154.8,
#   'duration': 4.719},
#  {'text': 'dining table', 'start': 157.84, 'duration': 4.64},
#  {'text': "breakfast lunch dinner so she's thinking",
#   'start': 159.519,
#   'duration': 6.841},
#  {'text': 'when i have written multiplication',
#   'start': 162.48,
#   'duration': 3.88},
#  {'text': '6 times 7 is 30.', 'start': 171.12, 'duration': 5.839},
#  {'text': 'i want to apologize to maths teacher in',
#   'start': 173.92,
#   'duration': 5.679},
#  {'text': 'third standard of bulbul vidya mandir he',
#   'start': 176.959,
#   'duration': 4.481},
#  {'text': 'is going to third standard next year',
#   'start': 179.599,
#   'duration': 4.321},
#  {'text': 'teacher please i am sorry samhalin',
#   'start': 181.44,
#   'duration': 3.36},
#  {'text': 'and', 'start': 183.92, 'duration': 3.679},
#  {'text': 'our indian army should enroll my',
#   'start': 184.8,
#   'duration': 5.92},
#  {'text': 'pratibha if ever they have to fight a',
#   'start': 187.599,
#   'duration': 5.601},
#  {'text': 'war against mathematics', 'start': 190.72, 'duration': 4.879},
#  {'text': 'because that is her number any one enemy',
#   'start': 193.2,
#   'duration': 5.959},
#  {'text': 'she will fight properly', 'start': 195.599, 'duration': 3.56},
#  {'text': 'two', 'start': 201.44, 'duration': 4.68},
#  {'text': 'six sevens are thirty', 'start': 202.4, 'duration': 3.72}]

# %%
def remove_caption_overlaps(captions: list):
  for i in range(len(captions) - 1):
    captions[i]['duration'] = min(captions[i]['duration'], captions[i + 1]['start'] - captions[i]['start'])
  return captions

# %%
remove_caption_overlaps(fetch_captions('YieuqbIqUps'))
# Out:
# [{'text': 'sugar is okay for you know yes thank you',
#   'start': 0.16,
#   'duration': 3.1199999999999997},
#  {'text': 'how are you miss kulkarni how i am i am',
#   'start': 3.28,
#   'duration': 3.68},
#  {'text': 'worried like all other mothers',
#   'start': 6.96,
#   'duration': 1.9200000000000008},
#  {'text': 'everywhere all the time we are worried',
#   'start': 8.88,
#   'duration': 4.08},
#  {'text': 'your i am fine is my', 'start': 12.96, 'duration': 4.0},
#  {'text': 'ass toy means toy gun',
#   'start': 29.119,
#   'duration': 3.360999999999997},
#  {'text': 'it is not making any why we are doing do',
#   'start': 32.48,
#   'duration': 1.919000000000004},
#  {'text': 'you have to stop this', 'start': 34.399, 'duration': 2.0},
#  {'text': 'see last year my papa gave pratibha',
#   'start': 36.399,
#   'duration': 2.6409999999999982},
#  {'text': 'kitchen set', 'start': 39.04, 'duration': 1.5189999999999984},
#  {'text': 'my husband got so upset just because',
#   'start': 40.559,
#   'duration': 2.561},
#  {'text': "she's girl you are giving her kitchen",
#   'start': 43.12,
#   'duration': 1.8400000000000034},
#  {'text': 'set', 'start': 44.96, 'duration': 0.8800000000000026},
#  {'text': 'name but i understand but what',
#   'start': 45.84,
#   'duration': 2.479999999999997},
#  {'text': "prativha's papa has given pratibha",
#   'start': 48.32,
#   'duration': 2.719000000000001},
#  {'text': 'gun did you ask him why he got the gun i',
#   'start': 51.039,
#   'duration': 2.561},
#  {'text': "asked him he's telling no one day",
#   'start': 53.6,
#   'duration': 1.9200000000000017},
#  {'text': 'pratibha is going to become soldier huh',
#   'start': 55.52,
#   'duration': 3.5189999999999984},
#  {'text': 'that is why now she has to play with',
#   'start': 59.039,
#   'duration': 1.600999999999999},
#  {'text': 'tygan', 'start': 60.64, 'duration': 1.1199999999999974},
#  {'text': 'that means children who are one day',
#   'start': 61.76,
#   'duration': 2.240000000000002},
#  {'text': 'going to become charter accountant are',
#   'start': 64.0,
#   'duration': 2.159000000000006},
#  {'text': 'now playing with toy calculator',
#   'start': 66.159,
#   'duration': 3.4409999999999883},
#  {'text': 'so have you asked prativa if she wants',
#   'start': 69.6,
#   'duration': 1.7600000000000051},
#  {'text': 'to be a soldier that day she got the toy',
#   'start': 71.36,
#   'duration': 2.6400000000000006},
#  {'text': 'gun pratibha decided she is going to be',
#   'start': 74.0,
#   'duration': 2.8799999999999955},
#  {'text': 'shikari shambo shikari shambhu you know',
#   'start': 76.88,
#   'duration': 2.960000000000008},
#  {'text': 'comics', 'start': 79.84, 'duration': 1.4399999999999977},
#  {'text': 'both are same shikhari shampoo and my',
#   'start': 81.28,
#   'duration': 1.8389999999999986},
#  {'text': 'protiba', 'start': 83.119, 'duration': 1.0400000000000063},
#  {'text': 'lazy liars telling tall stories all the',
#   'start': 84.159,
#   'duration': 3.040999999999997},
#  {'text': 'time and now she also has gun she curry',
#   'start': 87.2,
#   'duration': 2.719999999999999},
#  {'text': 'shambo soldier whatever',
#   'start': 89.92,
#   'duration': 2.719999999999999},
#  {'text': 'summer holidays are on the corner what',
#   'start': 92.64,
#   'duration': 2.0},
#  {'text': 'holiday plans', 'start': 94.64, 'duration': 1.5999999999999943},
#  {'text': 'yes summer holidays',
#   'start': 96.24,
#   'duration': 2.5200000000000102},
#  {'text': '[Music]', 'start': 98.76, 'duration': 3.119},
#  {'text': "and come back that's all sum up the",
#   'start': 112.479,
#   'duration': 2.1610000000000014},
#  {'text': 'summer holidays are you not enrolling',
#   'start': 114.64,
#   'duration': 1.8389999999999986},
#  {'text': 'pratibha in any hobby classes coding is',
#   'start': 116.479,
#   'duration': 2.239999999999995},
#  {'text': 'very popular these days',
#   'start': 118.719,
#   'duration': 1.9210000000000065},
#  {'text': 'oh', 'start': 120.64, 'duration': 0.8799999999999955},
#  {'text': 'computer coding', 'start': 121.52, 'duration': 2.0},
#  {'text': 'programmer', 'start': 123.52, 'duration': 1.5990000000000038},
#  {'text': 'means then they should have mini mbbs',
#   'start': 125.119,
#   'duration': 2.4809999999999945},
#  {'text': 'and junior is officer course also no',
#   'start': 127.6,
#   'duration': 4.159999999999997},
#  {'text': 'code audio', 'start': 131.76, 'duration': 1.5200000000000102},
#  {'text': 'maishikari shambu for last one year has',
#   'start': 133.28,
#   'duration': 2.0800000000000125},
#  {'text': 'not been able to decode multiplication',
#   'start': 135.36,
#   'duration': 2.319999999999993},
#  {'text': 'and division', 'start': 137.68, 'duration': 1.2789999999999964},
#  {'text': 'that the teacher is asking pratibha',
#   'start': 138.959,
#   'duration': 4.241},
#  {'text': 'teacher has not asked what do you want',
#   'start': 148.48,
#   'duration': 1.8389999999999986},
#  {'text': 'to have nasta', 'start': 150.319, 'duration': 1.600999999999999},
#  {'text': 'teacher is asking multiplication tables',
#   'start': 151.92,
#   'duration': 2.880000000000024},
#  {'text': 'but my pratibha knows only one table',
#   'start': 154.8,
#   'duration': 3.039999999999992},
#  {'text': 'dining table', 'start': 157.84, 'duration': 1.679000000000002},
#  {'text': "breakfast lunch dinner so she's thinking",
#   'start': 159.519,
#   'duration': 2.9609999999999843},
#  {'text': 'when i have written multiplication',
#   'start': 162.48,
#   'duration': 3.88},
#  {'text': '6 times 7 is 30.', 'start': 171.12, 'duration': 2.799999999999983},
#  {'text': 'i want to apologize to maths teacher in',
#   'start': 173.92,
#   'duration': 3.0390000000000157},
#  {'text': 'third standard of bulbul vidya mandir he',
#   'start': 176.959,
#   'duration': 2.6399999999999864},
#  {'text': 'is going to third standard next year',
#   'start': 179.599,
#   'duration': 1.8410000000000082},
#  {'text': 'teacher please i am sorry samhalin',
#   'start': 181.44,
#   'duration': 2.4799999999999898},
#  {'text': 'and', 'start': 183.92, 'duration': 0.8800000000000239},
#  {'text': 'our indian army should enroll my',
#   'start': 184.8,
#   'duration': 2.798999999999978},
#  {'text': 'pratibha if ever they have to fight a',
#   'start': 187.599,
#   'duration': 3.1210000000000093},
#  {'text': 'war against mathematics',
#   'start': 190.72,
#   'duration': 2.4799999999999898},
#  {'text': 'because that is her number any one enemy',
#   'start': 193.2,
#   'duration': 2.399000000000001},
#  {'text': 'she will fight properly', 'start': 195.599, 'duration': 3.56},
#  {'text': 'two', 'start': 201.44, 'duration': 0.960000000000008},
#  {'text': 'six sevens are thirty', 'start': 202.4, 'duration': 3.72}]

# %%
def fuse_captions_most_replayed(captions: list, most_replayed: list):
  # ind for iterating over most_replayed
  ind = 0
  n = len(most_replayed)

  for caption in captions:
    end_dur = caption['start'] + caption['duration']
    intensity = 0
    count = 0

    while ind < n and most_replayed[ind]['heatMarkerRenderer']['timeRangeStartMillis'] / 1000 < caption['start']:
      ind += 1
    
    while ind < n and most_replayed[ind]['heatMarkerRenderer']['timeRangeStartMillis'] / 1000 < end_dur:
      intensity += most_replayed[ind]['heatMarkerRenderer']['heatMarkerIntensityScoreNormalized']
      count += 1
      ind += 1
    
    if count:
      intensity = intensity / count

    caption['intensity'] = intensity
  return captions

# %%
def get_fused_captions_intensity(video_id: str):
  most_replayed = fetch_most_replayed(video_id)
  captions = fetch_captions(video_id)
  remove_caption_overlaps(captions)
  return fuse_captions_most_replayed(captions, most_replayed)

# %%
get_fused_captions_intensity('YieuqbIqUps')
# Out:
# [{'text': 'sugar is okay for you know yes thank you',
#   'start': 0.16,
#   'duration': 3.1199999999999997,
#   'intensity': 0.4254768856939025},
#  {'text': 'how are you miss kulkarni how i am i am',
#   'start': 3.28,
#   'duration': 3.68,
#   'intensity': 0.35719972877484435},
#  {'text': 'worried like all other mothers',
#   'start': 6.96,
#   'duration': 1.9200000000000008,
#   'intensity': 0.2926660463058963},
#  {'text': 'everywhere all the time we are worried',
#   'start': 8.88,
#   'duration': 4.08,
#   'intensity': 0.3355336270705944},
#  {'text': 'your i am fine is my',
#   'start': 12.96,
#   'duration': 4.0,
#   'intensity': 0.3564911949914417},
#  {'text': 'ass toy means toy gun',
#   'start': 29.119,
#   'duration': 3.360999999999997,
#   'intensity': 0.17579769399583717},
#  {'text': 'it is not making any why we are doing do',
#   'start': 32.48,
#   'duration': 1.919000000000004,
#   'intensity': 0.14911336176971499},
#  {'text': 'you have to stop this',
#   'start': 34.399,
#   'duration': 2.0,
#   'intensity': 0.1206053114242384},
#  {'text': 'see last year my papa gave pratibha',
#   'start': 36.399,
#   'duration': 2.6409999999999982,
#   'intensity': 0.12096678658124449},
#  {'text': 'kitchen set',
#   'start': 39.04,
#   'duration': 1.5189999999999984,
#   'intensity': 0.10671533514618056},
#  {'text': 'my husband got so upset just because',
#   'start': 40.559,
#   'duration': 2.561,
#   'intensity': 0.10352595222084585},
#  {'text': "she's girl you are giving her kitchen",
#   'start': 43.12,
#   'duration': 1.8400000000000034,
#   'intensity': 0.08275927284387466},
#  {'text': 'set',
#   'start': 44.96,
#   'duration': 0.8800000000000026,
#   'intensity': 0.06420453201727867},
#  {'text': 'name but i understand but what',
#   'start': 45.84,
#   'duration': 2.479999999999997,
#   'intensity': 0.06710486440380051},
#  {'text': "prativha's papa has given pratibha",
#   'start': 48.32,
#   'duration': 2.719000000000001,
#   'intensity': 0.058916311013916214},
#  {'text': 'gun did you ask him why he got the gun i',
#   'start': 51.039,
#   'duration': 2.561,
#   'intensity': 0.052270605370818186},
#  {'text': "asked him he's telling no one day",
#   'start': 53.6,
#   'duration': 1.9200000000000017,
#   'intensity': 0},
#  {'text': 'pratibha is going to become soldier huh',
#   'start': 55.52,
#   'duration': 3.5189999999999984,
#   'intensity': 0.043644237604726376},
#  {'text': 'that is why now she has to play with',
#   'start': 59.039,
#   'duration': 1.600999999999999,
#   'intensity': 0.05785465322232497},
#  {'text': 'tygan',
#   'start': 60.64,
#   'duration': 1.1199999999999974,
#   'intensity': 0},
#  {'text': 'that means children who are one day',
#   'start': 61.76,
#   'duration': 2.240000000000002,
#   'intensity': 0.04783528143677484},
#  {'text': 'going to become charter accountant are',
#   'start': 64.0,
#   'duration': 2.159000000000006,
#   'intensity': 0.054880546355193294},
#  {'text': 'now playing with toy calculator',
#   'start': 66.159,
#   'duration': 3.4409999999999883,
#   'intensity': 0.05043714124481576},
#  {'text': 'so have you asked prativa if she wants',
#   'start': 69.6,
#   'duration': 1.7600000000000051,
#   'intensity': 0.05624154963629487},
#  {'text': 'to be a soldier that day she got the toy',
#   'start': 71.36,
#   'duration': 2.6400000000000006,
#   'intensity': 0.03632038808076526},
#  {'text': 'gun pratibha decided she is going to be',
#   'start': 74.0,
#   'duration': 2.8799999999999955,
#   'intensity': 0.03717306017301493},
#  {'text': 'shikari shambo shikari shambhu you know',
#   'start': 76.88,
#   'duration': 2.960000000000008,
#   'intensity': 0.053647204062373145},
#  {'text': 'comics',
#   'start': 79.84,
#   'duration': 1.4399999999999977,
#   'intensity': 0.05257930090733432},
#  {'text': 'both are same shikhari shampoo and my',
#   'start': 81.28,
#   'duration': 1.8389999999999986,
#   'intensity': 0.09815612753485714},
#  {'text': 'protiba',
#   'start': 83.119,
#   'duration': 1.0400000000000063,
#   'intensity': 0},
#  {'text': 'lazy liars telling tall stories all the',
#   'start': 84.159,
#   'duration': 3.040999999999997,
#   'intensity': 0.12885406867790405},
#  {'text': 'time and now she also has gun she curry',
#   'start': 87.2,
#   'duration': 2.719999999999999,
#   'intensity': 0.13761512571592652},
#  {'text': 'shambo soldier whatever',
#   'start': 89.92,
#   'duration': 2.719999999999999,
#   'intensity': 0.19527728855764104},
#  {'text': 'summer holidays are on the corner what',
#   'start': 92.64,
#   'duration': 2.0,
#   'intensity': 0.2315816042765657},
#  {'text': 'holiday plans',
#   'start': 94.64,
#   'duration': 1.5999999999999943,
#   'intensity': 0.24929478687814224},
#  {'text': 'yes summer holidays',
#   'start': 96.24,
#   'duration': 2.5200000000000102,
#   'intensity': 0.4560522413313545},
#  {'text': '[Music]',
#   'start': 98.76,
#   'duration': 3.119,
#   'intensity': 0.4936913010078361},
#  {'text': "and come back that's all sum up the",
#   'start': 112.479,
#   'duration': 2.1610000000000014,
#   'intensity': 0.2113756397492942},
#  {'text': 'summer holidays are you not enrolling',
#   'start': 114.64,
#   'duration': 1.8389999999999986,
#   'intensity': 0.14600248684253106},
#  {'text': 'pratibha in any hobby classes coding is',
#   'start': 116.479,
#   'duration': 2.239999999999995,
#   'intensity': 0.09514154279339232},
#  {'text': 'very popular these days',
#   'start': 118.719,
#   'duration': 1.9210000000000065,
#   'intensity': 0.09377375420387653},
#  {'text': 'oh',
#   'start': 120.64,
#   'duration': 0.8799999999999955,
#   'intensity': 0},
#  {'text': 'computer coding',
#   'start': 121.52,
#   'duration': 2.0,
#   'intensity': 0.08052195688006696},
#  {'text': 'programmer',
#   'start': 123.52,
#   'duration': 1.5990000000000038,
#   'intensity': 0.06807989702457566},
#  {'text': 'means then they should have mini mbbs',
#   'start': 125.119,
#   'duration': 2.4809999999999945,
#   'intensity': 0.08168381045930274},
#  {'text': 'and junior is officer course also no',
#   'start': 127.6,
#   'duration': 4.159999999999997,
#   'intensity': 0.0863894308436507},
#  {'text': 'code audio',
#   'start': 131.76,
#   'duration': 1.5200000000000102,
#   'intensity': 0.0886571637072463},
#  {'text': 'maishikari shambu for last one year has',
#   'start': 133.28,
#   'duration': 2.0800000000000125,
#   'intensity': 0.07439237563150614},
#  {'text': 'not been able to decode multiplication',
#   'start': 135.36,
#   'duration': 2.319999999999993,
#   'intensity': 0.06680712075102457},
#  {'text': 'and division',
#   'start': 137.68,
#   'duration': 1.2789999999999964,
#   'intensity': 0.07767295526170791},
#  {'text': 'that the teacher is asking pratibha',
#   'start': 138.959,
#   'duration': 4.241,
#   'intensity': 0.06876739995152734},
#  {'text': 'teacher has not asked what do you want',
#   'start': 148.48,
#   'duration': 1.8389999999999986,
#   'intensity': 0},
#  {'text': 'to have nasta',
#   'start': 150.319,
#   'duration': 1.600999999999999,
#   'intensity': 0.05033658549386012},
#  {'text': 'teacher is asking multiplication tables',
#   'start': 151.92,
#   'duration': 2.880000000000024,
#   'intensity': 0.04908915963649321},
#  {'text': 'but my pratibha knows only one table',
#   'start': 154.8,
#   'duration': 3.039999999999992,
#   'intensity': 0.05746936649228964},
#  {'text': 'dining table',
#   'start': 157.84,
#   'duration': 1.679000000000002,
#   'intensity': 0.054133172530523},
#  {'text': "breakfast lunch dinner so she's thinking",
#   'start': 159.519,
#   'duration': 2.9609999999999843,
#   'intensity': 0.09344269594665833},
#  {'text': 'when i have written multiplication',
#   'start': 162.48,
#   'duration': 3.88,
#   'intensity': 0.10636051931042981},
#  {'text': '6 times 7 is 30.',
#   'start': 171.12,
#   'duration': 2.799999999999983,
#   'intensity': 0.12845719112925133},
#  {'text': 'i want to apologize to maths teacher in',
#   'start': 173.92,
#   'duration': 3.0390000000000157,
#   'intensity': 0.08840234567931898},
#  {'text': 'third standard of bulbul vidya mandir he',
#   'start': 176.959,
#   'duration': 2.6399999999999864,
#   'intensity': 0.05663205583434114},
#  {'text': 'is going to third standard next year',
#   'start': 179.599,
#   'duration': 1.8410000000000082,
#   'intensity': 0.05848460701491461},
#  {'text': 'teacher please i am sorry samhalin',
#   'start': 181.44,
#   'duration': 2.4799999999999898,
#   'intensity': 0.055108943076085916},
#  {'text': 'and',
#   'start': 183.92,
#   'duration': 0.8800000000000239,
#   'intensity': 0},
#  {'text': 'our indian army should enroll my',
#   'start': 184.8,
#   'duration': 2.798999999999978,
#   'intensity': 0.053768349714723676},
#  {'text': 'pratibha if ever they have to fight a',
#   'start': 187.599,
#   'duration': 3.1210000000000093,
#   'intensity': 0.07586572346200186},
#  {'text': 'war against mathematics',
#   'start': 190.72,
#   'duration': 2.4799999999999898,
#   'intensity': 0.07970714392906217},
#  {'text': 'because that is her number any one enemy',
#   'start': 193.2,
#   'duration': 2.399000000000001,
#   'intensity': 0.08331430027325895},
#  {'text': 'she will fight properly',
#   'start': 195.599,
#   'duration': 3.56,
#   'intensity': 0.08852017966920739},
#  {'text': 'two',
#   'start': 201.44,
#   'duration': 0.960000000000008,
#   'intensity': 0.032283741511930135},
#  {'text': 'six sevens are thirty',
#   'start': 202.4,
#   'duration': 3.72,
#   'intensity': 0.0}]

# %%
import nltk
nltk.download('punkt')
def str_to_sentences(string_data: str):
  return nltk.tokenize.sent_tokenize(string_data)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def create_chunks(sentences: list):
  # initialize
  length = 0
  chunk = ""
  chunks = []
  count = -1
  for sentence in sentences:
    count += 1
    combined_length = len(tokenizer.tokenize(sentence)) + length # add the no. of sentence tokens to the length counter

    if combined_length  <= tokenizer.max_len_single_sentence: # if it doesn't exceed
      chunk += sentence + " " # add the sentence to the chunk
      length = combined_length # update the length counter

      # if it is the last sentence
      if count == len(sentences) - 1:
        chunks.append(chunk.strip()) # save the chunk
      
    else: 
      chunks.append(chunk.strip()) # save the chunk
      
      # reset 
      length = 0 
      chunk = ""

      # take care of the overflow sentence
      chunk += sentence + " "
      length = len(tokenizer.tokenize(sentence))
  return chunks

# %%
def summary(chunks):
  inputs = [tokenizer(chunk, return_tensors="pt") for chunk in chunks]
  outputs = ''
  for input in inputs:
    output = model.generate(**input)
    outputs += tokenizer.decode(*output, skip_special_tokens=True)
  return outputs

# %%
def get_summary(long_string: str):
  sents = str_to_sentences(long_string)
  chunks = create_chunks(sents)
  summ = summary(chunks)
  return summ

# %%
def process_video_list(video_ids: list, filepath: str):
  result = []
  for id in video_ids:
    fused_captions = get_fused_captions_intensity(id)
    text_captions = ' '.join([caption['text'] for caption in fused_captions])

    ARTICLE = rpunct.punctuate(text_captions)

    result.append({
        'id': id,
        'text_captions': ARTICLE,
        'fused_captions': fused_captions,
        'summary': get_summary(ARTICLE)
    })

  # Serializing json
  json_object = json.dumps(result, indent=4)
  
  # Writing to sample.json
  with open(filepath, "w") as outfile:
      outfile.write(json_object)
  return result

# %%
cnn10_video_ids = [
    '8GgaCgjAFLM',
    'Kc_GMYHJNFQ',
    'wPdiuj2JwEU',
    'H07TJT3VpSY',
    'U4WxR7hXfCQ',
    '1xbEbTJASoE',
    'rQp4putiL_A',
    'rQp4putiL_A',
    '94N_3jBAU_c',
    'owDr-ra0P6I'
]
process_video_list(cnn10_video_ids, 'data/cnn10.json')
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1273: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 142 (`generation_config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'id': '8GgaCgjAFLM',
#   'text_captions': "[music] Thank you Hello lovely people Happy! Friday Eve It's Thursday March 2nd I'm Coy Wire and we are so grateful that you're spending part of your day with us right here on CNN 10. Let's start today with the latest reporting on the origins of Covet 19. it's been nearly three years since the pandemic began, and we're still trying to figure out answers about how exactly this virus was able to infect so many people and take so many lives. Reporting this week states that with quote low confidence, the U.S Department of Energy and the Director of the FBI endorse a lab leak theory meaning the virus accidentally escaped from a lab in Wuhan China Low confidence according to the office of the Director of National Intelligence generally means that the information is scant, questionable, or very fragmented, or that the intelligence Community has significant concerns about the sources. One of the main reasons that there is so much uncertainty about the virus's origins is that China has not been transparent and willing to to communicate openly with their knowledge and information. Now, others within the U.S Intelligence community and many scientists maintain, however, that this virus developed naturally in animals and then started to spread to humans in an outbreak at a market. Republicans In the House of Representatives on a coveted subcommittee are committed to investigating the issue and finding the origin of the virus. Here's CNN Chief Investigative Correspondent: Pamela Brown With more more than three years after the start of the Covid-19 Pandemic, the theory that the virus originated from a lab in Wuhan China in the spotlight, the Department of Energy now saying in an updated classified report that it believes with low confidence that the virus accidentally escaped from a lab, but that theory remains a minority opinion within the U.S Intelligence Community Some elements of the Intelligence Community have reached conclusions on one side, some on the other. A number of them have said they just don't have enough information to be sure. Early in the pandemic, many prominent scientists discredited the so-called lab leak Theory One group writing a letter published in the Landsat Medical Journal saying We Stand Together to strongly condone conspiracy theories suggesting that Covid-19 does not have a natural origin, but other medical professionals have long refused to rule it out. These kinds of lab leaks happen all the time. Actually, even here in the United States we've had mishaps and in China the last six known outbreaks of SARS one have been out of labs even. Dr Anthony Fauci. The longtime director of the National Institute of Allergy and Infectious Diseases agreed it was possible it might possibly have been something the Chinese were doing a virus that they isolated in the wild and we're having it in the lab and then somehow it escaped out. I Don't think that happened, but I Have an open mind. According to the intelligence community's assessment, first published in 2021, the origins of the virus will remain elusive until China cooperates with global investigations. Why at this point do you say it's possible? Maybe even probable that the virus came from a lab and accidentally leaked out? The SARS Kobe 2 virus has an ancestral origin and a type of horseshoe bat that doesn't exist in Wuhan. If this comes from Nature, there would have to be some evidence of it coming from nature. Right now, we don't have that evidence now. House Republicans Are demanding more information from the State Department FBI and Doe on the origins of Covet 19. I Want to make sure that we are readying ourselves for the next pandemic. If we will and the more we can learn about natural versions and or possible lab leak, then the better off we're going to be. 10 Second trivia. An object traveling at a supersonic speed is traveling faster than 200 miles per hour. The speed of light, the speed of sound, or the speed of a hedgehog. Foreign. [Music] ...
#   'fused_captions': [{'text': '[Music]',
#     'start': 0.0,
#     'duration': 2.81,
#     'intensity': 1.0},
#    {'text': 'thank you',
#     'start': 9.08,
#     'duration': 2.3200000000000003,
#     'intensity': 0},
#    {'text': 'hello lovely people happy Friday Eve',
#     'start': 11.4,
#     'duration': 2.76,
#     'intensity': 0.5225561666879905},
#    {'text': "it's Thursday March 2nd I'm Coy wire and",
#     'start': 14.16,
#     'duration': 2.3999999999999986,
#     'intensity': 0},
#    {'text': "we are so grateful that you're spending",
#     'start': 16.56,
#     'duration': 1.3800000000000026,
#     'intensity': 0},
#    {'text': 'part of your day with us right here on',
#     'start': 17.94,
#     'duration': 2.039999999999999,
#     'intensity': 0.4202848071035898},
#    {'text': "CNN 10. let's start today with the",
#     'start': 19.98,
#     'duration': 2.039999999999999,
#     'intensity': 0},
#    {'text': 'latest reporting on the origins of covet',
#     'start': 22.02,
#     'duration': 2.6400000000000006,
#     'intensity': 0.49030226053094145},
#    {'text': "19. it's been nearly three years since",
#     'start': 24.66,
#     'duration': 2.279,
#     'intensity': 0},
#    {'text': "the pandemic began and we're still",
#     'start': 26.939,
#     'duration': 1.6799999999999997,
#     'intensity': 0},
#    {'text': 'trying to figure out answers about how',
#     'start': 28.619,
#     'duration': 2.641000000000002,
#     'intensity': 0.626980839854372},
#    {'text': 'exactly this virus was able to infect so',
#     'start': 31.26,
#     'duration': 2.34,
#     'intensity': 0},
#    {'text': 'many people and take so many lives',
#     'start': 33.6,
#     'duration': 2.039999999999999,
#     'intensity': 0},
#    {'text': 'reporting this week states that with',
#     'start': 35.64,
#     'duration': 2.519999999999996,
#     'intensity': 0.6894280372877767},
#    {'text': 'quote low confidence the U.S department',
#     'start': 38.16,
#     'duration': 2.280000000000001,
#     'intensity': 0},
#    {'text': 'of energy and the director of the FBI',
#     'start': 40.44,
#     'duration': 2.539999999999999,
#     'intensity': 0.6418873979771129},
#    {'text': 'endorse a lab leak theory meaning the',
#     'start': 42.98,
#     'duration': 3.0990000000000038,
#     'intensity': 0},
#    {'text': 'virus accidentally escaped from a lab in',
#     'start': 46.079,
#     'duration': 2.341000000000001,
#     'intensity': 0.4934509815957902},
#    {'text': 'Wuhan China low confidence according to',
#     'start': 48.42,
#     'duration': 2.519999999999996,
#     'intensity': 0},
#    {'text': 'the office of the Director of National',
#     'start': 50.94,
#     'duration': 1.6189999999999998,
#     'intensity': 0},
#    {'text': 'Intelligence generally means that the',
#     'start': 52.559,
#     'duration': 2.4610000000000056,
#     'intensity': 0.32023573334915095},
#    {'text': 'information is scant questionable or',
#     'start': 55.02,
#     'duration': 2.6399999999999935,
#     'intensity': 0},
#    {'text': 'very fragmented or that the intelligence',
#     'start': 57.66,
#     'duration': 2.5790000000000006,
#     'intensity': 0.32506792904273074},
#    {'text': 'Community has significant concerns about',
#     'start': 60.239,
#     'duration': 2.2210000000000036,
#     'intensity': 0},
#    {'text': 'the sources one of the main reasons that',
#     'start': 62.46,
#     'duration': 2.3999999999999986,
#     'intensity': 0},
#    {'text': 'there is so much uncertainty about the',
#     'start': 64.86,
#     'duration': 2.0999999999999943,
#     'intensity': 0.24647198330043932},
#    {'text': "virus's origins is that China has not",
#     'start': 66.96,
#     'duration': 2.940000000000012,
#     'intensity': 0},
#    {'text': 'been transparent and willing to to',
#     'start': 69.9,
#     'duration': 1.9199999999999875,
#     'intensity': 0},
#    {'text': 'communicate openly with their knowledge',
#     'start': 71.82,
#     'duration': 1.740000000000009,
#     'intensity': 0.28832186037465035},
#    {'text': 'and information now others within the',
#     'start': 73.56,
#     'duration': 2.5799999999999983,
#     'intensity': 0},
#    {'text': 'U.S intelligence community and many',
#     'start': 76.14,
#     'duration': 1.8599999999999994,
#     'intensity': 0},
#    {'text': 'scientists maintain however that this',
#     'start': 78.0,
#     'duration': 2.4599999999999937,
#     'intensity': 0.32760914254735896},
#    {'text': 'virus developed naturally in animals and',
#     'start': 80.46,
#     'duration': 2.159000000000006,
#     'intensity': 0},
#    {'text': 'then started to spread to humans in an',
#     'start': 82.619,
#     'duration': 2.1610000000000014,
#     'intensity': 0.38751733358807083},
#    {'text': 'outbreak at a market Republicans in the',
#     'start': 84.78,
#     'duration': 2.6400000000000006,
#     'intensity': 0},
#    {'text': 'House of Representatives on a coveted',
#     'start': 87.42,
#     'duration': 1.8599999999999994,
#     'intensity': 0},
#    {'text': 'subcommittee are committed to',
#     'start': 89.28,
#     'duration': 1.3790000000000049,
#     'intensity': 0.33142137663778914},
#    {'text': 'investigating the issue and finding the',
#     'start': 90.659,
#     'duration': 2.040999999999997,
#     'intensity': 0},
#    {'text': "origin of the virus here's CNN Chief",
#     'start': 92.7,
#     'duration': 2.519999999999996,
#     'intensity': 0},
#    {'text': 'investigative correspondent Pamela Brown',
#     'start': 95.22,
#     'duration': 1.980000000000004,
#     'intensity': 0.18321884514937148},
#    {'text': 'with more',
#     'start': 97.2,
#     'duration': 1.9399999999999977,
#     'intensity': 0},
#    {'text': 'more than three years after the start of',
#     'start': 99.14,
#     'duration': 2.9200000000000017,
#     'intensity': 0},
#    {'text': 'the covid-19 pandemic the theory that',
#     'start': 102.06,
#     'duration': 2.698999999999998,
#     'intensity': 0.0557339905928751},
#    {'text': 'the virus originated from a lab in Wuhan',
#     'start': 104.759,
#     'duration': 2.521000000000001,
#     'intensity': 0},
#    {'text': 'China in the spotlight',
#     'start': 107.28,
#     'duration': 2.3389999999999986,
#     'intensity': 0.1937051788157258},
#    {'text': 'the department of energy now saying in',
#     'start': 109.619,
#     'duration': 2.340999999999994,
#     'intensity': 0},
#    {'text': 'an updated classified report that it',
#     'start': 111.96,
#     'duration': 2.220000000000013,
#     'intensity': 0},
#    {'text': 'believes with low confidence that the',
#     'start': 114.18,
#     'duration': 2.3989999999999867,
#     'intensity': 0.1949535075319419},
#    {'text': 'virus accidentally escaped from a lab',
#     'start': 116.579,
#     'duration': 2.281000000000006,
#     'intensity': 0},
#    {'text': 'but that theory remains a minority',
#     'start': 118.86,
#     'duration': 2.0999999999999943,
#     'intensity': 0.22581024286163098},
#    {'text': 'opinion within the U.S intelligence',
#     'start': 120.96,
#     'duration': 2.0400000000000063,
#     'intensity': 0},
#    {'text': 'Community some elements of the',
#     'start': 123.0,
#     'duration': 1.7990000000000066,
#     'intensity': 0},
#    {'text': 'intelligence Community have reached',
#     'start': 124.799,
#     'duration': 1.3810000000000002,
#     'intensity': 0},
#    {'text': 'conclusions on one side some on the',
#     'start': 126.18,
#     'duration': 1.6799999999999926,
#     'intensity': 0.1650888690172179},
#    {'text': 'other a number of them have said they',
#     'start': 127.86,
#     'duration': 1.7999999999999972,
#     'intensity': 0},
#    {'text': "just don't have enough information to be",
#     'start': 129.66,
#     'duration': 1.740000000000009,
#     'intensity': 0},
#    {'text': 'sure early in the pandemic many',
#     'start': 131.4,
#     'duration': 1.978999999999985,
#     'intensity': 0.22749757993624894},
#    {'text': 'prominent scientists discredited the',
#     'start': 133.379,
#     'duration': 2.1610000000000014,
#     'intensity': 0},
#    {'text': 'so-called lab leak Theory one group',
#     'start': 135.54,
#     'duration': 2.3389999999999986,
#     'intensity': 0},
#    {'text': 'writing a letter published in the',
#     'start': 137.879,
#     'duration': 1.6810000000000116,
#     'intensity': 0.3287033182893365},
#    {'text': 'landsat medical journal saying We Stand',
#     'start': 139.56,
#     'duration': 2.1599999999999966,
#     'intensity': 0},
#    {'text': 'Together to strongly condone conspiracy',
#     'start': 141.72,
#     'duration': 2.280000000000001,
#     'intensity': 0},
#    {'text': 'theories suggesting that covid-19 does',
#     'start': 144.0,
#     'duration': 2.5800000000000125,
#     'intensity': 0.33356668943900386},
#    {'text': 'not have a natural origin but other',
#     'start': 146.58,
#     'duration': 2.280000000000001,
#     'intensity': 0},
#    {'text': 'medical professionals have long refused',
#     'start': 148.86,
#     'duration': 2.4589999999999748,
#     'intensity': 0.38321346531402894},
#    {'text': 'to rule it out these kinds of lab leaks',
#     'start': 151.319,
#     'duration': 2.341000000000008,
#     'intensity': 0},
#    {'text': 'happen all the time actually even here',
#     'start': 153.66,
#     'duration': 2.218999999999994,
#     'intensity': 0},
#    {'text': "in the United States we've had mishaps",
#     'start': 155.879,
#     'duration': 1.7410000000000139,
#     'intensity': 0.30485119754789863},
#    {'text': 'and in China the last six known',
#     'start': 157.62,
#     'duration': 1.740000000000009,
#     'intensity': 0},
#    {'text': 'outbreaks of SARS one have been out of',
#     'start': 159.36,
#     'duration': 2.6999999999999886,
#     'intensity': 0},
#    {'text': 'labs even Dr Anthony fauci the longtime',
#     'start': 162.06,
#     'duration': 2.5200000000000102,
#     'intensity': 0.25572943842450835},
#    {'text': 'director of the National Institute of',
#     'start': 164.58,
#     'duration': 1.9199999999999875,
#     'intensity': 0},
#    {'text': 'allergy and infectious diseases agreed',
#     'start': 166.5,
#     'duration': 2.4000000000000057,
#     'intensity': 0.26287413564840983},
#    {'text': 'it was possible it might possibly have',
#     'start': 168.9,
#     'duration': 2.3389999999999986,
#     'intensity': 0},
#    {'text': 'been something the Chinese were doing a',
#     'start': 171.239,
#     'duration': 2.219999999999999,
#     'intensity': 0},
#    {'text': 'virus that they isolated in the wild and',
#     'start': 173.459,
#     'duration': 2.2210000000000036,
#     'intensity': 0.2636914567869899},
#    {'text': "we're having it in the lab and then",
#     'start': 175.68,
#     'duration': 1.8599999999999852,
#     'intensity': 0},
#    {'text': "somehow it escaped out I don't think",
#     'start': 177.54,
#     'duration': 1.9190000000000111,
#     'intensity': 0},
#    {'text': 'that happened but I have an open mind',
#     'start': 179.459,
#     'duration': 2.1610000000000014,
#     'intensity': 0.21837268947280028},
#    {'text': 'according to the intelligence',
#     'start': 181.62,
#     'duration': 1.5,
#     'intensity': 0},
#    {'text': "community's assessment first published",
#     'start': 183.12,
#     'duration': 2.039999999999992,
#     'intensity': 0},
#    {'text': 'in 2021 the origins of the virus will',
#     'start': 185.16,
#     'duration': 2.8799999999999955,
#     'intensity': 0.23472035374486544},
#    {'text': 'remain elusive until China cooperates',
#     'start': 188.04,
#     'duration': 2.4000000000000057,
#     'intensity': 0},
#    {'text': 'with global investigations why at this',
#     'start': 190.44,
#     'duration': 2.640000000000015,
#     'intensity': 0.23410746634930235},
#    {'text': "point do you say it's possible maybe",
#     'start': 193.08,
#     'duration': 2.219999999999999,
#     'intensity': 0},
#    {'text': 'even probable that the virus came from a',
#     'start': 195.3,
#     'duration': 2.518999999999977,
#     'intensity': 0},
#    {'text': 'lab and accidentally leaked out the SARS',
#     'start': 197.819,
#     'duration': 2.700000000000017,
#     'intensity': 0.34039687321211},
#    {'text': 'Kobe 2 virus has an ancestral origin and',
#     'start': 200.519,
#     'duration': 2.400999999999982,
#     'intensity': 0},
#    {'text': "a type of horseshoe bat that doesn't",
#     'start': 202.92,
#     'duration': 2.160000000000025,
#     'intensity': 0.27424917673000504},
#    {'text': 'exist in Wuhan if this comes from nature',
#     'start': 205.08,
#     'duration': 2.938999999999993,
#     'intensity': 0},
#    {'text': 'there would have to be some evidence of',
#     'start': 208.019,
#     'duration': 2.8810000000000002,
#     'intensity': 0.07996532075371493},
#    {'text': "it coming from nature right now we don't",
#     'start': 210.9,
#     'duration': 3.180000000000007,
#     'intensity': 0},
#    {'text': 'have that evidence now House Republicans',
#     'start': 214.08,
#     'duration': 2.3999999999999773,
#     'intensity': 0.12214240217234992},
#    {'text': 'are demanding more information from the',
#     'start': 216.48,
#     'duration': 2.280000000000001,
#     'intensity': 0},
#    {'text': 'state department FBI and doe on the',
#     'start': 218.76,
#     'duration': 2.8799999999999955,
#     'intensity': 0},
#    {'text': 'origins of covet 19. I want to make sure',
#     'start': 221.64,
#     'duration': 2.819000000000017,
#     'intensity': 0.22902531522903788},
#    {'text': 'that we are readying ourselves for the',
#     'start': 224.459,
#     'duration': 2.5209999999999866,
#     'intensity': 0},
#    {'text': 'next pandemic if we will and the more we',
#     'start': 226.98,
#     'duration': 1.8000000000000114,
#     'intensity': 0.328140366801312},
#    {'text': 'can learn about natural versions and or',
#     'start': 228.78,
#     'duration': 2.0389999999999873,
#     'intensity': 0},
#    {'text': 'possible lab leak then the better off',
#     'start': 230.819,
#     'duration': 3.1210000000000093,
#     'intensity': 0},
#    {'text': "we're going to be",
#     'start': 233.94,
#     'duration': 2.218999999999994,
#     'intensity': 0.5036739102471034},
#    {'text': '10 second trivia an object traveling at',
#     'start': 236.159,
#     'duration': 2.4610000000000127,
#     'intensity': 0},
#    {'text': 'a supersonic speed is traveling faster',
#     'start': 238.62,
#     'duration': 2.3389999999999986,
#     'intensity': 0.43338360260673714},
#    {'text': 'than 200 miles per hour the speed of',
#     'start': 240.959,
#     'duration': 2.4609999999999843,
#     'intensity': 0},
#    {'text': 'light the speed of sound or the speed of',
#     'start': 243.42,
#     'duration': 2.219999999999999,
#     'intensity': 0},
#    {'text': 'a hedgehog',
#     'start': 245.64,
#     'duration': 1.5600000000000023,
#     'intensity': 0.42987415668494544},
#    {'text': 'foreign',
#     'start': 247.2,
#     'duration': 1.0100000000000193,
#     'intensity': 0},
#    {'text': '[Music]',
#     'start': 248.21,
#     'duration': 2.6689999999999827,
#     'intensity': 0},
#    {'text': 'supersonic object is traveling faster',
#     'start': 250.879,
#     'duration': 2.320999999999998,
#     'intensity': 0.3717479326430821},
#    {'text': 'than the speed of sound',
#     'start': 253.2,
#     'duration': 3.38,
#     'intensity': 0},
#    {'text': 'continuing now with our series on the',
#     'start': 258.12,
#     'duration': 2.2799999999999727,
#     'intensity': 0.3431597635217506},
#    {'text': 'future of travel we take to the skies',
#     'start': 260.4,
#     'duration': 2.340000000000032,
#     'intensity': 0},
#    {'text': "where one company says that they'll be",
#     'start': 262.74,
#     'duration': 1.6789999999999736,
#     'intensity': 0},
#    {'text': 'able to take passengers in planes that',
#     'start': 264.419,
#     'duration': 2.2200000000000273,
#     'intensity': 0.38934013215772434},
#    {'text': 'fly twice as fast as commercial planes',
#     'start': 266.639,
#     'duration': 2.521000000000015,
#     'intensity': 0},
#    {'text': 'being used today and that means getting',
#     'start': 269.16,
#     'duration': 2.0989999999999895,
#     'intensity': 0.2947795940086567},
#    {'text': "to where you're going twice as fast but",
#     'start': 271.259,
#     'duration': 2.100999999999999,
#     'intensity': 0},
#    {'text': "here's the thing you'd have to be",
#     'start': 273.36,
#     'duration': 1.558999999999969,
#     'intensity': 0},
#    {'text': 'willing to break the sound barrier to do',
#     'start': 274.919,
#     'duration': 2.2800000000000296,
#     'intensity': 0.2067221042605192},
#    {'text': "so and that means you'd be going so fast",
#     'start': 277.199,
#     'duration': 2.2799999999999727,
#     'intensity': 0},
#    {'text': 'that the aircraft would create a sonic',
#     'start': 279.479,
#     'duration': 1.9809999999999945,
#     'intensity': 0},
#    {'text': 'boom which according to NASA is as loud',
#     'start': 281.46,
#     'duration': 2.819999999999993,
#     'intensity': 0.1643065168083644},
#    {'text': "as an explosion or Thunderclap here's",
#     'start': 284.28,
#     'duration': 2.63900000000001,
#     'intensity': 0},
#    {'text': 'CNN business correspondent Rahel Solomon',
#     'start': 286.919,
#     'duration': 2.1610000000000014,
#     'intensity': 0.22220809823855225},
#    {'text': 'with more', 'start': 289.08, 'duration': 2.54, 'intensity': 0},
#    {'text': 'thank you',
#     'start': 294.32,
#     'duration': 3.659,
#     'intensity': 0.10684325401409862},
#    {'text': 'planes are a ubiquitous mode of',
#     'start': 298.68,
#     'duration': 2.159999999999968,
#     'intensity': 0.08103597695913084},
#    {'text': "transportation today they've allowed us",
#     'start': 300.84,
#     'duration': 1.9800000000000182,
#     'intensity': 0},
#    {'text': 'to link cities countries and continents',
#     'start': 302.82,
#     'duration': 2.340000000000032,
#     'intensity': 0},
#    {'text': 'like never before',
#     'start': 305.16,
#     'duration': 2.0989999999999895,
#     'intensity': 0.014664051698838197},
#    {'text': 'but what if we could fly faster and',
#     'start': 307.259,
#     'duration': 2.5809999999999604,
#     'intensity': 0},
#    {'text': "experience more in a way that's also",
#     'start': 309.84,
#     'duration': 2.2200000000000273,
#     'intensity': 0},
#    {'text': 'better for the planet',
#     'start': 312.06,
#     'duration': 1.5,
#     'intensity': 0.01258867675707664},
#    {'text': 'I believe in a future where more people',
#     'start': 313.56,
#     'duration': 2.2199999999999704,
#     'intensity': 0},
#    {'text': 'can go more places more often I think',
#     'start': 315.78,
#     'duration': 2.4600000000000364,
#     'intensity': 0},
#    {'text': 'that life happens in person',
#     'start': 318.24,
#     'duration': 2.6399999999999864,
#     'intensity': 0.00030982333793263276},
#    {'text': 'that connecting across oceans is',
#     'start': 320.88,
#     'duration': 3.240000000000009,
#     'intensity': 0},
#    {'text': "incredibly important to our future I'm",
#     'start': 324.12,
#     'duration': 2.339999999999975,
#     'intensity': 0.08937203182241578},
#    {'text': 'Blake Scholl founder and CEO at boom',
#     'start': 326.46,
#     'duration': 2.459000000000003,
#     'intensity': 0},
#    {'text': 'supersonic', 'start': 328.919, 'duration': 1.5, 'intensity': 0},
#    {'text': 'the Last Frontier in air travel was more',
#     'start': 330.419,
#     'duration': 2.5810000000000173,
#     'intensity': 0.1886554446520126},
#    {'text': 'than half a century ago when we went',
#     'start': 333.0,
#     'duration': 1.6200000000000045,
#     'intensity': 0},
#    {'text': 'from propeller aircraft into the jet age',
#     'start': 334.62,
#     'duration': 1.8589999999999804,
#     'intensity': 0},
#    {'text': "and it's been a long time since we had a",
#     'start': 336.479,
#     'duration': 2.2200000000000273,
#     'intensity': 0.15631284018405933},
#    {'text': 'step forward',
#     'start': 338.699,
#     'duration': 1.620999999999981,
#     'intensity': 0},
#    {'text': 'I think the next Frontier is all about',
#     'start': 340.32,
#     'duration': 2.158999999999992,
#     'intensity': 0},
#    {'text': 'making the planet more accessible about',
#     'start': 342.479,
#     'duration': 2.5810000000000173,
#     'intensity': 0.037741407178700545},
#    {'text': 'having flights that are faster more',
#     'start': 345.06,
#     'duration': 1.8000000000000114,
#     'intensity': 0},
#    {'text': 'affordable more convenient and',
#     'start': 346.86,
#     'duration': 1.3799999999999955,
#     'intensity': 0},
#    {'text': 'dramatically more sustainable',
#     'start': 348.24,
#     'duration': 2.5190000000000055,
#     'intensity': 0.036262504237482486},
#    {'text': 'just under a decade old colorado-based',
#     'start': 350.759,
#     'duration': 3.2409999999999854,
#     'intensity': 0},
#    {'text': 'startup boom is working to bring',
#     'start': 354.0,
#     'duration': 1.978999999999985,
#     'intensity': 0.07970315723913747},
#    {'text': 'supersonic travel back to the skies I',
#     'start': 355.979,
#     'duration': 3.0,
#     'intensity': 0},
#    {'text': 'started my career as a software engineer',
#     'start': 358.979,
#     'duration': 1.68100000000004,
#     'intensity': 0.07318659027760295},
#    {'text': "but I've been passionate about Aviation",
#     'start': 360.66,
#     'duration': 1.67999999999995,
#     'intensity': 0},
#    {'text': 'since I was a kid and I never understood',
#     'start': 362.34,
#     'duration': 2.340000000000032,
#     'intensity': 0},
#    {'text': 'as a tech guy why everything in our',
#     'start': 364.68,
#     'duration': 3.1200000000000045,
#     'intensity': 0.19116224100489806},
#    {'text': 'world was getting faster and better but',
#     'start': 367.8,
#     'duration': 1.5600000000000023,
#     'intensity': 0},
#    {'text': "our flights weren't",
#     'start': 369.36,
#     'duration': 1.8000000000000114,
#     'intensity': 0},
#    {'text': 'commercial supersonic air travel was',
#     'start': 371.16,
#     'duration': 2.159999999999968,
#     'intensity': 0.18159075523576956},
#    {'text': 'first realized in the 1970s when Concord',
#     'start': 373.32,
#     'duration': 2.819000000000017,
#     'intensity': 0},
#    {'text': 'took flight but after just 27 years the',
#     'start': 376.139,
#     'duration': 2.940999999999974,
#     'intensity': 0.15580672182837152},
#    {'text': 'fleet was retired due to a number of',
#     'start': 379.08,
#     'duration': 1.740000000000009,
#     'intensity': 0},
#    {'text': 'issues including noise expensive',
#     'start': 380.82,
#     'duration': 2.759999999999991,
#     'intensity': 0},
#    {'text': 'overhead and cost prohibitive tickets',
#     'start': 383.58,
#     'duration': 3.5,
#     'intensity': 0.11494183742758345},
#    {'text': 'the supersonic airplane fundamentally is',
#     'start': 387.08,
#     'duration': 3.0400000000000205,
#     'intensity': 0},
#    {'text': 'about being able to go very efficiently',
#     'start': 390.12,
#     'duration': 1.9800000000000182,
#     'intensity': 0.0090619877732896},
#    {'text': 'at very high speed',
#     'start': 392.1,
#     'duration': 2.7799999999999727,
#     'intensity': 0},
#    {'text': 'supersonic means flying faster than the',
#     'start': 394.88,
#     'duration': 2.5,
#     'intensity': 0.05490453033865029},
#    {'text': 'speed of sound according to NASA typical',
#     'start': 397.38,
#     'duration': 2.6999999999999886,
#     'intensity': 0},
#    {'text': 'speeds for these aircraft range from',
#     'start': 400.08,
#     'duration': 1.920000000000016,
#     'intensity': 0},
#    {'text': 'about 1200 kilometers per hour to about',
#     'start': 402.0,
#     'duration': 2.9599999999999795,
#     'intensity': 0.10742544875930995},
#    {'text': '2400. these speeds are achievable',
#     'start': 404.96,
#     'duration': 2.6790000000000305,
#     'intensity': 0},
#    {'text': 'through powerful engines and a long lean',
#     'start': 407.639,
#     'duration': 3.0,
#     'intensity': 0.12499730146079772},
#    {'text': 'fuselage design the downside supersonic',
#     'start': 410.639,
#     'duration': 3.0600000000000023,
#     'intensity': 0},
#    {'text': 'travel creates a shock wave or sonic',
#     'start': 413.699,
#     'duration': 2.2799999999999727,
#     'intensity': 0.16496747786077054},
#    {'text': 'boom that is loud and disruptive over',
#     'start': 415.979,
#     'duration': 2.9399999999999977,
#     'intensity': 0},
#    {'text': "land which is why it's only intended for",
#     'start': 418.919,
#     'duration': 2.521000000000015,
#     'intensity': 0.20970743006989992},
#    {'text': "long hauls across oceans we're building",
#     'start': 421.44,
#     'duration': 2.7590000000000146,
#     'intensity': 0},
#    {'text': 'on a proven foundation and delivering a',
#     'start': 424.199,
#     'duration': 2.5809999999999604,
#     'intensity': 0.116913202219389},
#    {'text': "new capability to passengers it doesn't",
#     'start': 426.78,
#     'duration': 1.9790000000000418,
#     'intensity': 0},
#    {'text': 'require a massive regulatory change or',
#     'start': 428.759,
#     'duration': 2.4010000000000105,
#     'intensity': 0},
#    {'text': "any regulatory change at all we've now",
#     'start': 431.16,
#     'duration': 2.158999999999992,
#     'intensity': 0.10719397789508424},
#    {'text': "built xb1 which is history's first",
#     'start': 433.319,
#     'duration': 2.099999999999966,
#     'intensity': 0},
#    {'text': 'independently developed supersonic chat',
#     'start': 435.419,
#     'duration': 1.86099999999999,
#     'intensity': 0},
#    {'text': "and it's going to be in the air here in",
#     'start': 437.28,
#     'duration': 1.740000000000009,
#     'intensity': 0.0},
#    {'text': 'the next few months to prove that all of',
#     'start': 439.02,
#     'duration': 2.2800000000000296,
#     'intensity': 0},
#    {'text': 'this technology actually works',
#     'start': 441.3,
#     'duration': 2.599999999999966,
#     'intensity': 0},
#    {'text': "xb1 is boom's prototype of what will be",
#     'start': 443.9,
#     'duration': 2.980000000000018,
#     'intensity': 0.12164807807106694},
#    {'text': 'their first airliner Overture according',
#     'start': 446.88,
#     'duration': 2.519999999999982,
#     'intensity': 0},
#    {'text': "to Shoal it's expected to be capable of",
#     'start': 449.4,
#     'duration': 2.400000000000034,
#     'intensity': 0.20920538107684303},
#    {'text': 'going twice as fast as regular aircraft',
#     'start': 451.8,
#     'duration': 3.1189999999999714,
#     'intensity': 0},
#    {'text': 'therefore nearly having transit times',
#     'start': 454.919,
#     'duration': 2.7200000000000273,
#     'intensity': 0.36149079375677007},
#    {'text': 'think San Francisco to Tokyo in six',
#     'start': 457.639,
#     'duration': 3.521000000000015,
#     'intensity': 0},
#    {'text': 'hours or New York to Frankfurt and a',
#     'start': 461.16,
#     'duration': 3.2399999999999523,
#     'intensity': 0.24629237956669564},
#    {'text': 'little over four',
#     'start': 464.4,
#     'duration': 1.6200000000000045,
#     'intensity': 0},
#    {'text': 'with orders already placed from U.S',
#     'start': 466.02,
#     'duration': 2.459000000000003,
#     'intensity': 0},
#    {'text': 'carriers American and United boom has a',
#     'start': 468.479,
#     'duration': 3.2410000000000423,
#     'intensity': 0.16386399086531547},
#    {'text': 'sky-high goal to get Overture into',
#     'start': 471.72,
#     'duration': 1.7999999999999545,
#     'intensity': 0},
#    {'text': 'service by 2029.',
#     'start': 473.52,
#     'duration': 3.86,
#     'intensity': 0.17129678516903546},
#    {'text': 'on board the airplane expect a large',
#     'start': 477.66,
#     'duration': 3.478999999999985,
#     'intensity': 0.14648229465151255},
#    {'text': 'spacious interior and beautiful large',
#     'start': 481.139,
#     'duration': 2.5810000000000173,
#     'intensity': 0},
#    {'text': "windows it's a supersonic airplane",
#     'start': 483.72,
#     'duration': 1.7399999999999523,
#     'intensity': 0},
#    {'text': "actually flies higher you'll be able to",
#     'start': 485.46,
#     'duration': 2.2200000000000273,
#     'intensity': 0.14240355179488204},
#    {'text': 'see the skies a deeper blue actually see',
#     'start': 487.68,
#     'duration': 2.2799999999999727,
#     'intensity': 0},
#    {'text': 'the curvature of the Earth all of that',
#     'start': 489.96,
#     'duration': 1.799000000000035,
#     'intensity': 0},
#    {'text': 'adds up to a machine that can take you',
#     'start': 491.759,
#     'duration': 2.5809999999999604,
#     'intensity': 0.16897469649624428},
#    {'text': 'across oceans but at roughly the same',
#     'start': 494.34,
#     'duration': 2.160000000000025,
#     'intensity': 0},
#    {'text': 'cost as flying business class today',
#     'start': 496.5,
#     'duration': 1.5600000000000023,
#     'intensity': 0},
#    {'text': 'ultimately our goal is to make',
#     'start': 498.06,
#     'duration': 1.978999999999985,
#     'intensity': 0.04306068488752523},
#    {'text': 'supersonic flight available to anybody',
#     'start': 500.039,
#     'duration': 2.340000000000032,
#     'intensity': 0},
#    {'text': 'who flies',
#     'start': 502.379,
#     'duration': 1.3799999999999955,
#     'intensity': 0},
#    {'text': 'there are many challenges we still have',
#     'start': 503.759,
#     'duration': 2.040999999999997,
#     'intensity': 0.05369758497122305},
#    {'text': "left to overcome what we're doing is",
#     'start': 505.8,
#     'duration': 1.6789999999999736,
#     'intensity': 0},
#    {'text': "complex it's safety critical it requires",
#     'start': 507.479,
#     'duration': 2.2200000000000273,
#     'intensity': 0},
#    {'text': 'a lot of money but when I look back to',
#     'start': 509.699,
#     'duration': 1.86099999999999,
#     'intensity': 0.03078121071814939},
#    {'text': 'the past I also see a lot of challenges',
#     'start': 511.56,
#     'duration': 1.8589999999999804,
#     'intensity': 0},
#    {'text': "that we've already overcome and that",
#     'start': 513.419,
#     'duration': 1.8000000000000682,
#     'intensity': 0},
#    {'text': 'gives me encouragement that we will',
#     'start': 515.219,
#     'duration': 2.5809999999999036,
#     'intensity': 0.03719542286367945},
#    {'text': 'continue to do things that the world',
#     'start': 517.8,
#     'duration': 1.5,
#     'intensity': 0},
#    {'text': "says we can't do supersonic flight is",
#     'start': 519.3,
#     'duration': 2.400000000000091,
#     'intensity': 0},
#    {'text': 'about making the planet dramatically',
#     'start': 521.7,
#     'duration': 1.8599999999999,
#     'intensity': 0.09432651531166662},
#    {'text': 'more accessible when that happens I',
#     'start': 523.56,
#     'duration': 2.4600000000000364,
#     'intensity': 0},
#    {'text': 'think we will live in a very different',
#     'start': 526.02,
#     'duration': 1.4389999999999645,
#     'intensity': 0},
#    {'text': 'more peaceful more harmonious more',
#     'start': 527.459,
#     'duration': 2.701000000000022,
#     'intensity': 0.3712238815029191},
#    {'text': 'collaborative future',
#     'start': 530.16,
#     'duration': 2.84,
#     'intensity': 0},
#    {'text': '[Applause]',
#     'start': 533.92,
#     'duration': 3.17,
#     'intensity': 0.4948736031826554},
#    {'text': "and for today's story getting a 10 out",
#     'start': 537.5,
#     'duration': 2.6200000000000045,
#     'intensity': 0},
#    {'text': 'of 10 Teamwork Makes the Dream work for',
#     'start': 540.12,
#     'duration': 2.399000000000001,
#     'intensity': 0.484673573317672},
#    {'text': 'two Eagles building one is in the nest',
#     'start': 542.519,
#     'duration': 2.520999999999958,
#     'intensity': 0},
#    {'text': 'then another flies in is like hey can',
#     'start': 545.04,
#     'duration': 1.8590000000000373,
#     'intensity': 0},
#    {'text': "you help me with this other one's like",
#     'start': 546.899,
#     'duration': 1.5,
#     'intensity': 0.509008085961492},
#    {'text': "what this stick and it's like yeah can",
#     'start': 548.399,
#     'duration': 1.8010000000000446,
#     'intensity': 0},
#    {'text': 'you help me put it over there sure no',
#     'start': 550.2,
#     'duration': 2.2199999999999136,
#     'intensity': 0},
#    {'text': 'problem they pick up the branch and Mark',
#     'start': 552.42,
#     'duration': 2.160000000000082,
#     'intensity': 0.7361281807845387},
#    {'text': 'it over in perfect Rhythm if I give DJ',
#     'start': 554.58,
#     'duration': 3.0,
#     'intensity': 0},
#    {'text': 'Nader a beat he can make them dance',
#     'start': 557.58,
#     'duration': 3.62,
#     'intensity': 0.7881812604471402},
#    {'text': 'in mind these Eagles get to get to be',
#     'start': 565.56,
#     'duration': 2.160000000000082,
#     'intensity': 0},
#    {'text': 'three feet tall so their nests can get',
#     'start': 567.72,
#     'duration': 2.2799999999999727,
#     'intensity': 0},
#    {'text': "to be about six feet wide that's wider",
#     'start': 570.0,
#     'duration': 2.2789999999999964,
#     'intensity': 0.26528899199473605},
#    {'text': 'than a queen-size bed well done my',
#     'start': 572.279,
#     'duration': 2.701000000000022,
#     'intensity': 0},
#    {'text': "feathery friends well that's about all",
#     'start': 574.98,
#     'duration': 1.9189999999999827,
#     'intensity': 0},
#    {'text': 'we have time for today thanks to',
#     'start': 576.899,
#     'duration': 1.8010000000000446,
#     'intensity': 0.18415369499851192},
#    {'text': "everyone who's reaching out at koi wire",
#     'start': 578.7,
#     'duration': 1.8599999999999,
#     'intensity': 0},
#    {'text': 'on Instagram Snapchat and Tick Tock and',
#     'start': 580.56,
#     'duration': 2.580000000000041,
#     'intensity': 0.1528849884316297},
#    {'text': 'thanks to everyone showing love on our',
#     'start': 583.14,
#     'duration': 1.6800000000000637,
#     'intensity': 0},
#    {'text': 'CNN 10 YouTube page Northside High',
#     'start': 584.82,
#     'duration': 3.0599999999999454,
#     'intensity': 0},
#    {'text': 'School in Jackson Tennessee we see you',
#     'start': 587.88,
#     'duration': 2.578999999999951,
#     'intensity': 0.23953130598606692},
#    {'text': 'and we are showing love right back at',
#     'start': 590.459,
#     'duration': 2.100999999999999,
#     'intensity': 0},
#    {'text': "you tomorrow's Friday can't wait crush",
#     'start': 592.56,
#     'duration': 2.6400000000001,
#     'intensity': 0.3876289306853048},
#    {'text': "it today and go be awesome I'm koi wire",
#     'start': 595.2,
#     'duration': 2.4599999999999227,
#     'intensity': 0},
#    {'text': 'and we are CNN 10.',
#     'start': 597.66,
#     'duration': 3.859,
#     'intensity': 0}],
#   'summary': " It's been nearly three years since the start of the Covid-19 Pandemic, the theory that the virus originated from a lab in Wuhan China in the spotlight. House Republicans are demanding more information from the State Department FBI and Doe on the origins of Covet 19. Blake Scholl, founder and CEO of Boom Supersonic, is working to bring supersonic air travel back to the skies. Boom has a sky-high goal to get Overture into service by 2029. Boom's prototype of what will be their first airliner, Overture, is expected to go twice as fast as regular aircraft."},
#  {'id': 'Kc_GMYHJNFQ',
#   'text_captions': "[music] Thank you hello everyone Wonderful! Wednesday to you I Know we're just halfway through the week, but we're gonna keep grinding and Shining because that's just what we do. I'm Coy This is CNN 10 and we've got a rendezvous with the news. We're going to start with news on a vegetable shortage in the United Kingdom Certain fruits and veggies are having to be rationed at most major supermarkets and four of the biggest supermarkets in the United Kingdom say they're putting purchase limits on some staple items like tomatoes, peppers, and cucumbers. Experts say this could go on for months. Some farmers are saying that they're not harvesting any tomatoes, peppers, or eggplants when they usually do at this time of year. A number of factors like bad weather conditions in Spain and Morocco high energy costs over the winter and even the impact of Brexit and the labor shortages are causing the lack of production. Here's CNN Anchor and Correspondent Issa Suarez in London who's been speaking with local shoppers: Row upon row of empty baskets, empty shelves, a supply Gap in fruit and veg has hit UK supermarkets. The shortages affecting Shoppers Nationwide I Went for lunch and I couldn't find it like tomatoes, cucumber or lettuce. It was quite annoying when you weren't trying to get your private day in and you can't actually get it. The fruits I want to, They're gone. Nothing there to deal with the shortages. Major British supermarkets are imposing limits on items like tomatoes, cucumbers and peppers. The UK's Minister for the environment, food and Rural Affairs said A disruption should only last a few weeks. and meanwhile encouraged people to eat more seasonally let them eat turnips. she said unconscious that consumers want a year-round choice and that is what our supermarkets and food and Growers food producers and Growers around the world try to satisfy supermarkets are blaming the recent shortages on poor weather conditions in key growing regions. Britain produces a fraction of the food it consumes, relying instead on overseas Imports and key supplies in southern Europe and North Africa In particular, Spain and Morocco have seen harvests hit by extreme weather conditions. but while climate change plays a significant role in warmer than average temperatures, the government faces another Inconvenient Truth Brexit, the cause of widespread supply chain disruption because of the interruption with trade, and Europe who kind of underpin our food supply? it means that there's less food coming in from Europe we're producing less food. So basically our food security is in real trouble. Labor shortages due to a lack of Migrant workers and soaring Energy prices following Russia's invasion of Ukraine have pushed the Gap even wider as Farmers struggle with front-end costs and those costs are passed on to the consumer consumers already grappling with record high grocery prices and the worst cost of living crisis in decades. 10 Second trivia. Where would you find the world's oldest? Airport Paris France Hamburg Germany Maryland USA or North Carolina USA Thank you Flights began at Maryland's College Park airport in 1909, when Wilbur Wright trained two military Pilots and up next. we're continuing with part two of our feature from yesterday on the future of travel. new technology in the years to come will likely change travel as we know it forever. The Planes Trains and Automobiles we use today May someday be as Antiquated as the Horse and Buggy Thought leaders in the travel industry are formulating plans that might make travel faster, cheaper and safer from hyperloops to air taxis to supersonic. Jets Here's CNN's Rahel Solomon with more on the next. Frontier From highways to railways, flight paths to bike Lanes We have plenty of Mobility options on the ground and in the air, but could the next Frontier in transit take place over water Once seed bearing startup is looking to turn coastlines into corridors, Water transportation is  ...
#   'fused_captions': [{'text': '[Music]',
#     'start': 0.0,
#     'duration': 2.81,
#     'intensity': 1.0},
#    {'text': 'thank you',
#     'start': 9.08,
#     'duration': 2.3200000000000003,
#     'intensity': 0},
#    {'text': 'hello everyone wonderful Wednesday to',
#     'start': 11.4,
#     'duration': 2.76,
#     'intensity': 0.639540476840493},
#    {'text': "you I know we're just halfway through",
#     'start': 14.16,
#     'duration': 1.379999999999999,
#     'intensity': 0},
#    {'text': "the week but we're gonna keep grinding",
#     'start': 15.54,
#     'duration': 1.5600000000000023,
#     'intensity': 0},
#    {'text': "and Shining because that's just what we",
#     'start': 17.1,
#     'duration': 1.6199999999999974,
#     'intensity': 0.7740713889449535},
#    {'text': "do I'm Coy this is CNN 10 and we've got",
#     'start': 18.72,
#     'duration': 2.399000000000001,
#     'intensity': 0},
#    {'text': "a rendezvous with the news we're going",
#     'start': 21.119,
#     'duration': 2.16,
#     'intensity': 0},
#    {'text': 'to start with news on a vegetable',
#     'start': 23.279,
#     'duration': 2.100999999999999,
#     'intensity': 0.9621674972553713},
#    {'text': 'shortage in the United Kingdom certain',
#     'start': 25.38,
#     'duration': 2.460000000000001,
#     'intensity': 0},
#    {'text': 'fruits and veggies are having to be',
#     'start': 27.84,
#     'duration': 1.9800000000000004,
#     'intensity': 0},
#    {'text': 'rationed at most major supermarkets and',
#     'start': 29.82,
#     'duration': 2.700000000000003,
#     'intensity': 0.9886355916020121},
#    {'text': 'four of the biggest supermarkets in the',
#     'start': 32.52,
#     'duration': 1.7399999999999949,
#     'intensity': 0},
#    {'text': "United Kingdom say they're putting",
#     'start': 34.26,
#     'duration': 1.6799999999999997,
#     'intensity': 0},
#    {'text': 'purchase limits on some staple items',
#     'start': 35.94,
#     'duration': 2.1000000000000014,
#     'intensity': 0.8491196375136078},
#    {'text': 'like tomatoes peppers and cucumbers',
#     'start': 38.04,
#     'duration': 2.6600000000000037,
#     'intensity': 0},
#    {'text': 'experts say this could go on for months',
#     'start': 40.7,
#     'duration': 2.979999999999997,
#     'intensity': 0.7374318523072071},
#    {'text': "some farmers are saying that they're not",
#     'start': 43.68,
#     'duration': 2.1000000000000014,
#     'intensity': 0},
#    {'text': 'harvesting any tomatoes peppers or',
#     'start': 45.78,
#     'duration': 2.3999999999999986,
#     'intensity': 0.7434613866729863},
#    {'text': 'eggplants when they usually do at this',
#     'start': 48.18,
#     'duration': 2.280000000000001,
#     'intensity': 0},
#    {'text': 'time of year a number of factors like',
#     'start': 50.46,
#     'duration': 2.0989999999999966,
#     'intensity': 0},
#    {'text': 'bad weather conditions in Spain and',
#     'start': 52.559,
#     'duration': 1.9209999999999994,
#     'intensity': 0.7481993462928781},
#    {'text': 'Morocco high energy costs over the',
#     'start': 54.48,
#     'duration': 2.399000000000001,
#     'intensity': 0},
#    {'text': 'winter and even the impact of brexit and',
#     'start': 56.879,
#     'duration': 2.4010000000000034,
#     'intensity': 0},
#    {'text': 'the labor shortages are causing the lack',
#     'start': 59.28,
#     'duration': 2.0989999999999966,
#     'intensity': 0.7553775030731085},
#    {'text': "of production here's CNN anchor and",
#     'start': 61.379,
#     'duration': 2.1600000000000037,
#     'intensity': 0},
#    {'text': 'correspondent Issa Suarez in London',
#     'start': 63.539,
#     'duration': 2.100999999999999,
#     'intensity': 0},
#    {'text': "who's been speaking with local shoppers",
#     'start': 65.64,
#     'duration': 3.780000000000001,
#     'intensity': 0.6111697447645218},
#    {'text': 'row upon row of empty baskets empty',
#     'start': 69.42,
#     'duration': 3.9599999999999937,
#     'intensity': 0.5627076966026995},
#    {'text': 'shelves',
#     'start': 73.38,
#     'duration': 1.2000000000000028,
#     'intensity': 0},
#    {'text': 'a supply Gap in fruit and veg has hit UK',
#     'start': 74.58,
#     'duration': 3.299999999999997,
#     'intensity': 0},
#    {'text': 'supermarkets the shortages affecting',
#     'start': 77.88,
#     'duration': 2.5200000000000102,
#     'intensity': 0.5806443751039845},
#    {'text': 'Shoppers Nationwide I went for lunch and',
#     'start': 80.4,
#     'duration': 3.5389999999999873,
#     'intensity': 0},
#    {'text': "I couldn't find it like tomatoes",
#     'start': 83.939,
#     'duration': 1.6800000000000068,
#     'intensity': 0.6348563508082997},
#    {'text': 'cucumber or lettuce it was quite',
#     'start': 85.619,
#     'duration': 1.7409999999999997,
#     'intensity': 0},
#    {'text': "annoying when you weren't trying to get",
#     'start': 87.36,
#     'duration': 1.6800000000000068,
#     'intensity': 0},
#    {'text': "your private day in and you can't",
#     'start': 89.04,
#     'duration': 1.1999999999999886,
#     'intensity': 0.6023136882292472},
#    {'text': 'actually get it the fruits I want to',
#     'start': 90.24,
#     'duration': 1.6200000000000045,
#     'intensity': 0},
#    {'text': "they're gone nothing there",
#     'start': 91.86,
# ...
#    {'text': "there's crew after crew with white hoses",
#     'start': 268.259,
#     'duration': 2.159999999999968,
#     'intensity': 0},
#    {'text': 'and black hoses All Through The Creeks',
#     'start': 270.419,
#     'duration': 1.5,
#     'intensity': 0.374037785209075},
#    {'text': "they're not telling us why and this is",
#     'start': 271.919,
#     'duration': 2.100999999999999,
#     'intensity': 0},
#    {'text': "go this is daily I'm driving my children",
#     'start': 274.02,
#     'duration': 2.1000000000000227,
#     'intensity': 0},
#    {'text': "to school past all of this and they're",
#     'start': 276.12,
#     'duration': 1.6800000000000068,
#     'intensity': 0.3670489341456705},
#    {'text': "asking me questions that I don't have",
#     'start': 277.8,
#     'duration': 1.920000000000016,
#     'intensity': 0},
#    {'text': 'answers to some of their questions',
#     'start': 279.72,
#     'duration': 1.8799999999999955,
#     'intensity': 0},
#    {'text': 'unanswered we found getting information',
#     'start': 281.6,
#     'duration': 2.4399999999999977,
#     'intensity': 0.3967593821007847},
#    {'text': 'just as challenging the keys tell me are',
#     'start': 284.04,
#     'duration': 3.0,
#     'intensity': 0},
#    {'text': 'they pumping water out or are you',
#     'start': 287.04,
#     'duration': 1.4389999999999645,
#     'intensity': 0},
#    {'text': 'pumping water back in to talk to the',
#     'start': 288.479,
#     'duration': 2.4010000000000105,
#     'intensity': 0.3956611619353393},
#    {'text': 'guys up at the top of the hill sir yeah',
#     'start': 290.88,
#     'duration': 1.740000000000009,
#     'intensity': 0},
#    {'text': "we're just grunts we're just trying to",
#     'start': 292.62,
#     'duration': 1.7989999999999782,
#     'intensity': 0},
#    {'text': 'get a sense of what what those pumps are',
#     'start': 294.419,
#     'duration': 1.86099999999999,
#     'intensity': 0.4093089287657873},
#    {'text': 'can just someone just Norfolk Southern',
#     'start': 296.28,
#     'duration': 1.6800000000000068,
#     'intensity': 0},
#    {'text': "can tell you everything that's the",
#     'start': 297.96,
#     'duration': 1.4399999999999977,
#     'intensity': 0},
#    {'text': 'hotline they can tell you everything you',
#     'start': 299.4,
#     'duration': 2.0400000000000205,
#     'intensity': 0.3927837653795615},
#    {'text': 'realize people are calling this number',
#     'start': 301.44,
#     'duration': 1.3799999999999955,
#     'intensity': 0},
#    {'text': "and no one is getting back to them we're",
#     'start': 302.82,
#     'duration': 2.2800000000000296,
#     'intensity': 0},
#    {'text': 'just told to direct people to that',
#     'start': 305.1,
#     'duration': 1.3789999999999623,
#     'intensity': 0},
#    {'text': 'number the governor asked by reporters',
#     'start': 306.479,
#     'duration': 2.2800000000000296,
#     'intensity': 0.3889323466882577},
#    {'text': 'Tuesday if he would feel comfortable',
#     'start': 308.759,
#     'duration': 2.159999999999968,
#     'intensity': 0},
#    {'text': 'living in East Palestine I I think that',
#     'start': 310.919,
#     'duration': 2.701000000000022,
#     'intensity': 0.35262148645418767},
#    {'text': 'I would be drinking the bottled water',
#     'start': 313.62,
#     'duration': 3.240000000000009,
#     'intensity': 0},
#    {'text': 'um and I would be continuing to uh',
#     'start': 316.86,
#     'duration': 5.119,
#     'intensity': 0.3547790463419536},
#    {'text': 'find out what the tests were showing as',
#     'start': 322.02,
#     'duration': 2.160000000000025,
#     'intensity': 0},
#    {'text': 'far as the air',
#     'start': 324.18,
#     'duration': 1.2199999999999704,
#     'intensity': 0.3594757185538571},
#    {'text': 'I would be alert and and concerned but I',
#     'start': 325.4,
#     'duration': 4.900000000000034,
#     'intensity': 0},
#    {'text': 'think I would probably be back in my',
#     'start': 330.3,
#     'duration': 1.5,
#     'intensity': 0.3749474535077046},
#    {'text': 'house but residents like Kathy Reese say',
#     'start': 331.8,
#     'duration': 2.399000000000001,
#     'intensity': 0},
#    {'text': 'they are left with few choices just',
#     'start': 334.199,
#     'duration': 2.4010000000000105,
#     'intensity': 0.4031070105582951},
#    {'text': "don't just pray and uh you drink a",
#     'start': 336.6,
#     'duration': 3.1200000000000045,
#     'intensity': 0},
#    {'text': 'bottle of water until we know for sure',
#     'start': 339.72,
#     'duration': 1.2589999999999577,
#     'intensity': 0},
#    {'text': "what's going on",
#     'start': 340.979,
#     'duration': 2.040999999999997,
#     'intensity': 0.4379111622095744},
#    {'text': '10 second trivia which of these is the',
#     'start': 343.02,
#     'duration': 2.1000000000000227,
#     'intensity': 0},
#    {'text': 'most visited Urban Park in the U.S',
#     'start': 345.12,
#     'duration': 1.6800000000000068,
#     'intensity': 0},
#    {'text': "Golden Gate Park in San Francisco DC's",
#     'start': 346.8,
#     'duration': 2.759999999999991,
#     'intensity': 0.4192354471659265},
#    {'text': 'National Mall Central Park in New York',
#     'start': 349.56,
#     'duration': 2.1000000000000227,
#     'intensity': 0},
#    {'text': 'or Lincoln Park in Chicago',
#     'start': 351.66,
#     'duration': 3.259,
#     'intensity': 0.44050122132125497},
#    {'text': 'with 40 million annual visitors Central',
#     'start': 356.36,
#     'duration': 2.740000000000009,
#     'intensity': 0},
#    {'text': 'Park is the most visited city park in',
#     'start': 359.1,
#     'duration': 2.339999999999975,
#     'intensity': 0.6160949311724745},
#    {'text': 'the U.S', 'start': 361.44, 'duration': 2.42, 'intensity': 0},
#    {'text': '[Applause]',
#     'start': 365.84,
#     'duration': 3.660000000000025,
#     'intensity': 0.498861802451028},
#    {'text': 'the park is also home to a wide range of',
#     'start': 369.5,
#     'duration': 3.2200000000000273,
#     'intensity': 0.5298236765810171},
#    {'text': 'wildlife as you can imagine but a',
#     'start': 372.72,
#     'duration': 1.5599999999999454,
#     'intensity': 0},
#    {'text': 'newcomer is getting most of the',
#     'start': 374.28,
#     'duration': 1.4400000000000546,
#     'intensity': 0},
#    {'text': 'attention right now Flacco the owl',
#     'start': 375.72,
#     'duration': 2.159999999999968,
#     'intensity': 0},
#    {'text': 'escaped from the Central Park Zoo and is',
#     'start': 377.88,
#     'duration': 2.0989999999999895,
#     'intensity': 0.5387232150006843},
#    {'text': 'at large and on the loose in the park',
#     'start': 379.979,
#     'duration': 2.040999999999997,
#     'intensity': 0},
#    {'text': 'the rare Eurasian eagle owl escaped his',
#     'start': 382.02,
#     'duration': 2.7000000000000455,
#     'intensity': 0.4734801250853328},
#    {'text': 'enclosure on February 2nd and since then',
#     'start': 384.72,
#     'duration': 2.7589999999999577,
#     'intensity': 0},
#    {'text': 'Zoo officials have kept an eye on the',
#     'start': 387.479,
#     'duration': 1.9209999999999923,
#     'intensity': 0},
#    {'text': 'bird which has become a bit of a',
#     'start': 389.4,
#     'duration': 1.5600000000000023,
#     'intensity': 0.4463865503406061},
#    {'text': 'celebrity while Flacco seems to be',
#     'start': 390.96,
#     'duration': 1.8590000000000373,
#     'intensity': 0},
#    {'text': 'adapting well to the wild there are some',
#     'start': 392.819,
#     'duration': 2.040999999999997,
#     'intensity': 0},
#    {'text': 'concerns over how he might adapt to that',
#     'start': 394.86,
#     'duration': 2.519999999999982,
#     'intensity': 0.4361145566550826},
#    {'text': 'New York City lifestyle',
#     'start': 397.38,
#     'duration': 1.9800000000000182,
#     'intensity': 0},
#    {'text': "there's a new star in Central Park and",
#     'start': 399.36,
#     'duration': 2.8799999999999955,
#     'intensity': 0},
#    {'text': "he's right out of Central Casting lately",
#     'start': 402.24,
#     'duration': 2.6999999999999886,
#     'intensity': 0.4342398245675404},
#    {'text': 'bird watchers only have eyes for owls',
#     'start': 404.94,
#     'duration': 3.0,
#     'intensity': 0},
#    {'text': "and some fans on David Barrett's birder",
#     'start': 407.94,
#     'duration': 3.0600000000000023,
#     'intensity': 0.416862826018305},
#    {'text': 'blog are saying let Flacco be free in',
#     'start': 411.0,
#     'duration': 3.478999999999985,
#     'intensity': 0},
#    {'text': 'the beginning of February Flacco escaped',
#     'start': 414.479,
#     'duration': 2.701000000000022,
#     'intensity': 0.4219922412186569},
#    {'text': 'from his exhibit at the Central Park Zoo',
#     'start': 417.18,
#     'duration': 1.920000000000016,
#     'intensity': 0},
#    {'text': 'after someone cut through the stainless',
#     'start': 419.1,
#     'duration': 1.8599999999999568,
#     'intensity': 0.4231743163836946},
#    {'text': "steel mesh his enclosure didn't have",
#     'start': 420.96,
#     'duration': 2.819999999999993,
#     'intensity': 0},
#    {'text': 'room to do much flying and his first',
#     'start': 423.78,
#     'duration': 1.9190000000000396,
#     'intensity': 0},
#    {'text': 'night of Freedom the NYPD almost',
#     'start': 425.699,
#     'duration': 2.9399999999999977,
#     'intensity': 0.4076648588682573},
#    {'text': 'corralled him on a Fifth Avenue sidewalk',
#     'start': 428.639,
#     'duration': 2.3999999999999773,
#     'intensity': 0},
#    {'text': 'well that was a hoot the NYPD tweeted',
#     'start': 431.039,
#     'duration': 3.1210000000000377,
#     'intensity': 0.39605892471320187},
#    {'text': 'when the owl flew off I was worried that',
#     'start': 434.16,
#     'duration': 2.8789999999999623,
#     'intensity': 0},
#    {'text': "it wouldn't be able to fly but it spread",
#     'start': 437.039,
#     'duration': 2.1000000000000227,
#     'intensity': 0.3818774354362209},
#    {'text': 'its wings and flew to the nearest set of',
#     'start': 439.139,
#     'duration': 1.9809999999999945,
#     'intensity': 0},
#    {'text': 'trees Zoo officials were most worried',
#     'start': 441.12,
#     'duration': 2.3999999999999773,
#     'intensity': 0},
#    {'text': "that Flaco didn't know how to hunt since",
#     'start': 443.52,
#     'duration': 2.759999999999991,
#     'intensity': 0.39263409395587057},
#    {'text': "he's always had his meals delivered they",
#     'start': 446.28,
#     'duration': 2.63900000000001,
#     'intensity': 0},
#    {'text': 'tried to lure him using a white rat in a',
#     'start': 448.919,
#     'duration': 2.761000000000024,
#     'intensity': 0.3913940028318126},
#    {'text': "cage hoping he'd get trapped in the wiry",
#     'start': 451.68,
#     'duration': 2.5790000000000077,
#     'intensity': 0},
#    {'text': 'filaments on top the zoo team was',
#     'start': 454.259,
#     'duration': 2.159999999999968,
#     'intensity': 0},
#    {'text': 'rushing with Nets to get Flaco but',
#     'start': 456.419,
#     'duration': 2.4610000000000127,
#     'intensity': 0.38730741230662313},
#    {'text': 'Flacco was too fast and now fans are',
#     'start': 458.88,
#     'duration': 2.6399999999999864,
#     'intensity': 0},
#    {'text': 'snapping photos of Flacco catching his',
#     'start': 461.52,
#     'duration': 2.5190000000000055,
#     'intensity': 0.3871879676851108},
#    {'text': 'own dinner rats',
#     'start': 464.039,
#     'duration': 3.0600000000000023,
#     'intensity': 0},
#    {'text': 'on the menu',
#     'start': 467.099,
#     'duration': 1.3799999999999955,
#     'intensity': 0},
#    {'text': 'Barrett says the owl is gone from zero',
#     'start': 468.479,
#     'duration': 2.701000000000022,
#     'intensity': 0.37724231376907624},
#    {'text': 'hunting skills to decent hunting skills',
#     'start': 471.18,
#     'duration': 2.6999999999999886,
#     'intensity': 0},
#    {'text': "that's just an incredible transformation",
#     'start': 473.88,
#     'duration': 2.340000000000032,
#     'intensity': 0.4076024551476305},
#    {'text': 'he hangs out in Central Park Charming',
#     'start': 476.22,
#     'duration': 3.0599999999999454,
#     'intensity': 0},
#    {'text': 'New Yorkers with hooting so low it',
#     'start': 479.28,
#     'duration': 2.400000000000034,
#     'intensity': 0.42157680551210114},
#    {'text': 'requires subtitles',
#     'start': 481.68,
#     'duration': 1.6399999999999864,
#     'intensity': 0},
#    {'text': '[Music]',
#     'start': 483.32,
#     'duration': 1.3600000000000136,
#     'intensity': 0},
#    {'text': 'like other creatures not native to',
#     'start': 484.68,
#     'duration': 2.3999999999999773,
#     'intensity': 0.4376434478104399},
#    {'text': 'Central Park Flaco the Eurasian eagle',
#     'start': 487.08,
#     'duration': 3.059000000000026,
#     'intensity': 0},
#    {'text': 'owl has become one of the select few all',
#     'start': 490.139,
#     'duration': 3.6610000000000014,
#     'intensity': 0.48542361217842733},
#    {'text': 'right I know you are all ready to flee',
#     'start': 493.8,
#     'duration': 2.0399999999999636,
#     'intensity': 0},
#    {'text': 'for the weekend like Flacco Monday is',
#     'start': 495.84,
#     'duration': 2.160000000000025,
#     'intensity': 0},
#    {'text': "President's day so no show that day",
#     'start': 498.0,
#     'duration': 1.6200000000000045,
#     'intensity': 0.5085926388717408},
#    {'text': 'originally established in 1885 in',
#     'start': 499.62,
#     'duration': 2.2799999999999727,
#     'intensity': 0},
#    {'text': 'recognition of President George',
#     'start': 501.9,
#     'duration': 1.2600000000000477,
#     'intensity': 0},
#    {'text': 'Washington the U.S holiday now',
#     'start': 503.16,
#     'duration': 2.0389999999999873,
#     'intensity': 0.4917156623222545},
#    {'text': 'recognizes all presidents past and',
#     'start': 505.199,
#     'duration': 2.5809999999999604,
#     'intensity': 0},
#    {'text': "present Fairmont West Virginia you're",
#     'start': 507.78,
#     'duration': 2.2200000000000273,
#     'intensity': 0},
#    {'text': 'getting the shout out today East',
#     'start': 510.0,
#     'duration': 1.5,
#     'intensity': 0.5412128431244811},
#    {'text': 'Fairmont Middle School rise up hornets',
#     'start': 511.5,
#     'duration': 2.3390000000000555,
#     'intensity': 0},
#    {'text': 'have a wonderful weekend everyone and',
#     'start': 513.839,
#     'duration': 1.9209999999999354,
#     'intensity': 0},
#    {'text': 'remember you are more powerful than you',
#     'start': 515.76,
#     'duration': 2.45900000000006,
#     'intensity': 0.6287614848136523},
#    {'text': "know it's been a blessing to spend this",
#     'start': 518.219,
#     'duration': 1.8009999999999309,
#     'intensity': 0},
#    {'text': 'week with you',
#     'start': 520.02,
#     'duration': 2.84,
#     'intensity': 0},
#    {'text': 'foreign', 'start': 523.08, 'duration': 3.0, 'intensity': 0},
#    {'text': '[Music]',
#     'start': 533.06,
#     'duration': 3.9300000000000637,
#     'intensity': 0.5847268843882102},
#    {'text': '[Applause]',
#     'start': 536.99,
#     'duration': 1.669999999999959,
#     'intensity': 0},
#    {'text': '[Music]',
#     'start': 538.66,
#     'duration': 9.519,
#     'intensity': 0.5125489067831016},
#    {'text': '[Music]',
#     'start': 551.86,
#     'duration': 3.74,
#     'intensity': 0.4967782250992396},
#    {'text': '[Music]',
#     'start': 560.35,
#     'duration': 11.819,
#     'intensity': 0.5334148156914643},
#    {'text': 'foreign', 'start': 573.72, 'duration': 3.0, 'intensity': 0},
#    {'text': '[Applause]',
#     'start': 578.5,
#     'duration': 6.71,
#     'intensity': 0.12729713031859172},
#    {'text': '[Music]',
#     'start': 587.92,
#     'duration': 3.34,
#     'intensity': 0.045535306306590695}],
#   'summary': " A toxic train derailment in Ohio led to the evacuation of much of the town of East Palestine. EPA Administrator Michael Regan visited the region on Thursday to assess the ongoing response and hear from impacted residents. Health officials are urging some East Palestine residents to drink bottled water until tests are complete. Flacco the rare Eurasian eagle owl escaped his enclosure on February 2nd and since then Zoo officials have kept an eye on the bird, which has become a bit of a celebrity. Zoo officials were most worried that Flaco didn't know how to hunt since he's always had his meals delivered."}]
