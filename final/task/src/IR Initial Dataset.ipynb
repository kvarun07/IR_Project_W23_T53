# %%
# !pip install youtube_transcript_api
# !pip install transformers
# !pip3 install git+https://github.com/ernie-mlg/rpunct.git
# !pip install tqdm
import requests
import json
from youtube_transcript_api import YouTubeTranscriptApi
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from tqdm import tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting youtube_transcript_api
#   Downloading youtube_transcript_api-0.6.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from youtube_transcript_api) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (3.4)
# Installing collected packages: youtube_transcript_api
# Successfully installed youtube_transcript_api-0.6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 55.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 76.5 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 22.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.28.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/ernie-mlg/rpunct.git
#   Cloning https://github.com/ernie-mlg/rpunct.git to /tmp/pip-req-build-d4viui48
#   Running command git clone --filter=blob:none --quiet https://github.com/ernie-mlg/rpunct.git /tmp/pip-req-build-d4viui48
#   Resolved https://github.com/ernie-mlg/rpunct.git to commit 4c378cf570f05aa58c7d3dbb896b51ca2d95fde6
#   Preparing metadata (setup.py) ... done
# Collecting langdetect==1.0.9
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pandas==1.2.4
#   Downloading pandas-1.2.4-cp39-cp39-manylinux1_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 61.8 MB/s eta 0:00:00
# Collecting simpletransformers==0.61.4
#   Downloading simpletransformers-0.61.4-py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.9/dist-packages (from rpunct==1.0.2) (1.16.0)
# Collecting torch==1.8.1
#   Downloading torch-1.8.1-cp39-cp39-manylinux1_x86_64.whl (804.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 804.1/804.1 MB 2.2 MB/s eta 0:00:00
# Collecting click==7.1.2
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 10.5 MB/s eta 0:00:00
# Collecting tqdm==4.49.0
#   Downloading tqdm-4.49.0-py2.py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.8/69.8 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/dist-packages (from pandas==1.2.4->rpunct==1.0.2) (2.8.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.9/dist-packages (from pandas==1.2.4->rpunct==1.0.2) (1.22.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas==1.2.4->rpunct==1.0.2) (2022.7.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (2.27.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (1.2.2)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.7 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.14.2-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 89.6 MB/s eta 0:00:00
# Collecting tensorboardx
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.9 MB/s eta 0:00:00
# Collecting streamlit
#   Downloading streamlit-1.21.0-py2.py3-none-any.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 83.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (1.10.1)
# Requirement already satisfied: transformers>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (4.28.1)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.9/dist-packages (from simpletransformers==0.61.4->rpunct==1.0.2) (0.13.3)
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 49.2 MB/s eta 0:00:00
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch==1.8.1->rpunct==1.0.2) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers>=4.2.0->simpletransformers==0.61.4->rpunct==1.0.2) (3.11.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.2.0->simpletransformers==0.61.4->rpunct==1.0.2) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.2.0->simpletransformers==0.61.4->rpunct==1.0.2) (23.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.2.0->simpletransformers==0.61.4->rpunct==1.0.2) (0.13.4)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets->simpletransformers==0.61.4->rpunct==1.0.2) (2023.4.0)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 15.0 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 77.0 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.10.1-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 52.7 MB/s eta 0:00:00
#   Downloading datasets-2.10.0-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 45.7 MB/s eta 0:00:00
#   Downloading datasets-2.9.0-py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.8/462.8 kB 48.4 MB/s eta 0:00:00
#   Downloading datasets-2.8.0-py3-none-any.whl (452 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 kB 44.0 MB/s eta 0:00:00
#   Downloading datasets-2.7.1-py3-none-any.whl (451 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.7/451.7 kB 38.1 MB/s eta 0:00:00
#   Downloading datasets-2.7.0-py3-none-any.whl (451 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.6/451.6 kB 44.6 MB/s eta 0:00:00
#   Downloading datasets-2.6.2-py3-none-any.whl (445 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.2/445.2 kB 42.2 MB/s eta 0:00:00
#   Downloading datasets-2.6.1-py3-none-any.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.9/441.9 kB 48.6 MB/s eta 0:00:00
#   Downloading datasets-2.6.0-py3-none-any.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.5/441.5 kB 45.2 MB/s eta 0:00:00
#   Downloading datasets-2.5.2-py3-none-any.whl (432 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.7/432.7 kB 47.0 MB/s eta 0:00:00
#   Downloading datasets-2.5.1-py3-none-any.whl (431 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.2/431.2 kB 45.0 MB/s eta 0:00:00
#   Downloading datasets-2.5.0-py3-none-any.whl (431 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.2/431.2 kB 44.9 MB/s eta 0:00:00
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 36.8 MB/s eta 0:00:00
#   Downloading datasets-2.3.2-py3-none-any.whl (362 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.3/362.3 kB 33.9 MB/s eta 0:00:00
#   Downloading datasets-2.3.1-py3-none-any.whl (362 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.3/362.3 kB 32.5 MB/s eta 0:00:00
#   Downloading datasets-2.3.0-py3-none-any.whl (361 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.9/361.9 kB 38.3 MB/s eta 0:00:00
#   Downloading datasets-2.2.2-py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 kB 38.3 MB/s eta 0:00:00
#   Downloading datasets-2.2.1-py3-none-any.whl (342 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.2/342.2 kB 35.2 MB/s eta 0:00:00
#   Downloading datasets-2.2.0-py3-none-any.whl (342 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.3/342.3 kB 31.3 MB/s eta 0:00:00
#   Downloading datasets-2.1.0-py3-none-any.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.4/325.4 kB 32.2 MB/s eta 0:00:00
#   Downloading datasets-2.0.0-py3-none-any.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 26.4 MB/s eta 0:00:00
#   Downloading datasets-1.18.4-py3-none-any.whl (312 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.1/312.1 kB 31.1 MB/s eta 0:00:00
#   Downloading datasets-1.18.3-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 kB 32.7 MB/s eta 0:00:00
#   Downloading datasets-1.18.2-py3-none-any.whl (312 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.0/312.0 kB 31.0 MB/s eta 0:00:00
#   Downloading datasets-1.18.1-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.5/311.5 kB 26.8 MB/s eta 0:00:00
#   Downloading datasets-1.18.0-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.3/311.3 kB 26.2 MB/s eta 0:00:00
#   Downloading datasets-1.17.0-py3-none-any.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.3/306.3 kB 23.3 MB/s eta 0:00:00
#   Downloading datasets-1.16.1-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.3/298.3 kB 29.3 MB/s eta 0:00:00
#   Downloading datasets-1.16.0-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.3/298.3 kB 29.5 MB/s eta 0:00:00
#   Downloading datasets-1.15.1-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.6/290.6 kB 26.1 MB/s eta 0:00:00
#   Downloading datasets-1.15.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.7/290.7 kB 31.4 MB/s eta 0:00:00
#   Downloading datasets-1.14.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 28.7 MB/s eta 0:00:00
#   Downloading datasets-1.13.3-py3-none-any.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.1/287.1 kB 28.1 MB/s eta 0:00:00
#   Downloading datasets-1.13.2-py3-none-any.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.1/287.1 kB 24.9 MB/s eta 0:00:00
#   Downloading datasets-1.13.1-py3-none-any.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.1/287.1 kB 32.3 MB/s eta 0:00:00
#   Downloading datasets-1.13.0-py3-none-any.whl (285 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.4/285.4 kB 34.1 MB/s eta 0:00:00
#   Downloading datasets-1.12.1-py3-none-any.whl (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.0/270.0 kB 27.5 MB/s eta 0:00:00
#   Downloading datasets-1.12.0-py3-none-any.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.6/269.6 kB 30.1 MB/s eta 0:00:00
#   Downloading datasets-1.11.0-py3-none-any.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.9/264.9 kB 31.2 MB/s eta 0:00:00
#   Downloading datasets-1.10.2-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 54.2 MB/s eta 0:00:00
#   Downloading datasets-1.10.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 48.3 MB/s eta 0:00:00
#   Downloading datasets-1.10.0-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 45.8 MB/s eta 0:00:00
#   Downloading datasets-1.9.0-py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.3/262.3 kB 30.3 MB/s eta 0:00:00
#   Downloading datasets-1.8.0-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 kB 27.8 MB/s eta 0:00:00
# Collecting pyarrow<4.0.0,>=1.0.0
#   Downloading pyarrow-3.0.0-cp39-cp39-manylinux2014_x86_64.whl (20.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.7/20.7 MB 71.0 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-1.7.0-py3-none-any.whl (234 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.9/234.9 kB 26.5 MB/s eta 0:00:00
#   Downloading datasets-1.6.2-py3-none-any.whl (221 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.8/221.8 kB 24.0 MB/s eta 0:00:00
#   Downloading datasets-1.6.1-py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 26.2 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 18.4 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-1.6.0-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.2/202.2 kB 26.7 MB/s eta 0:00:00
#   Downloading datasets-1.5.0-py3-none-any.whl (192 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.6/192.6 kB 24.3 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=0.17.1 in /usr/local/lib/python3.9/dist-packages (from datasets->simpletransformers==0.61.4->rpunct==1.0.2) (9.0.0)
#   Downloading datasets-1.4.1-py3-none-any.whl (186 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.8/186.8 kB 25.5 MB/s eta 0:00:00
#   Downloading datasets-1.4.0-py3-none-any.whl (186 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.8/186.8 kB 23.8 MB/s eta 0:00:00
#   Downloading datasets-1.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.1/181.1 kB 22.0 MB/s eta 0:00:00
#   Downloading datasets-1.2.1-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.7/159.7 kB 22.5 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers==0.61.4->rpunct==1.0.2) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers==0.61.4->rpunct==1.0.2) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers==0.61.4->rpunct==1.0.2) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers==0.61.4->rpunct==1.0.2) (1.26.15)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->simpletransformers==0.61.4->rpunct==1.0.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->simpletransformers==0.61.4->rpunct==1.0.2) (3.1.0)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 22.2 MB/s eta 0:00:00
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Collecting blinker>=1.0.0
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (13.3.3)
# Requirement already satisfied: altair<5,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (4.2.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (6.3.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (6.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (8.4.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (3.20.3)
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.10.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (5.3.0)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (4.3)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 22.7 MB/s eta 0:00:00
# Collecting watchdog
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 11.8 MB/s eta 0:00:00
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 68.3 MB/s eta 0:00:00
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb->simpletransformers==0.61.4->rpunct==1.0.2) (1.4.4)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb->simpletransformers==0.61.4->rpunct==1.0.2) (5.9.4)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.19.1-py2.py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 kB 28.3 MB/s eta 0:00:00
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from wandb->simpletransformers==0.61.4->rpunct==1.0.2) (67.6.1)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (3.1.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (4.3.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.12.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=1.4->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (3.15.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.11.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.11.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (2.2.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.9/dist-packages (from tzlocal>=1.1->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from validators>=0.2->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (4.4.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (2.1.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (22.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (0.1.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.9/dist-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit->simpletransformers==0.61.4->rpunct==1.0.2) (2023.3)
# Building wheels for collected packages: rpunct, langdetect, seqeval, validators, pathtools
#   Building wheel for rpunct (setup.py) ... done
#   Created wheel for rpunct: filename=rpunct-1.0.2-py3-none-any.whl size=5953 sha256=7315db773864c8acdc9dd412d101771dad1a70809f05cabeb9ab85bc0628a8d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lug2f5pd/wheels/b5/b3/bc/c9a2b7d8cdc733f1eea8c9c5a1d16fe339c33cbd02b24579c3
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993243 sha256=f27f7eee8d6a81027663b17e4e7721230751602a0032ec0c593554f5d81cd76a
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/d9/7e068de779d863bc8f8fc9467d85e25cfe47fa5051fff1a1bb
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=43fbb71d974b4a0e2c9f8f51d8aaace993a5f916d8ded54613657818fce955eb
#   Stored in directory: /root/.cache/pip/wheels/e2/a5/92/2c80d1928733611c2747a9820e1324a6835524d9411510c142
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=ab44ccab1e77eddb44c1d02bbaf9f50143dcfd3d8c53e84125f1187d4dbebe52
#   Stored in directory: /root/.cache/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=cbd40c83a2f0ba1efc3ec6f88dbbc7f28e113d06d8cd5b839ee4fcf4ffe1623e
#   Stored in directory: /root/.cache/pip/wheels/b7/0a/67/ada2a22079218c75a88361c0782855cc72aebc4d18d0289d05
# Successfully built rpunct langdetect seqeval validators pathtools
# Installing collected packages: sentencepiece, pathtools, xxhash, watchdog, validators, tqdm, torch, tensorboardx, smmap, setproctitle, sentry-sdk, pympler, langdetect, docker-pycreds, dill, click, blinker, pydeck, pandas, multiprocess, gitdb, seqeval, gitpython, datasets, wandb, streamlit, simpletransformers, rpunct
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yfinance 0.2.17 requires pandas>=1.3.0, but you have pandas 1.2.4 which is incompatible.
# xarray 2022.12.0 requires pandas>=1.3, but you have pandas 1.2.4 which is incompatible.
# torchvision 0.15.1+cu118 requires torch==2.0.0, but you have torch 1.8.1 which is incompatible.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.8.1 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.8.1 which is incompatible.
# torchaudio 2.0.1+cu118 requires torch==2.0.0, but you have torch 1.8.1 which is incompatible.
# plotnine 0.10.1 requires pandas>=1.3.5, but you have pandas 1.2.4 which is incompatible.
# mizani 0.8.1 requires pandas>=1.3.5, but you have pandas 1.2.4 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.5.3, but you have pandas 1.2.4 which is incompatible.
# flask 2.2.3 requires click>=8.0, but you have click 7.1.2 which is incompatible.
# arviz 0.15.1 requires pandas>=1.3.0, but you have pandas 1.2.4 which is incompatible.
# Successfully installed blinker-1.6.2 click-7.1.2 datasets-1.2.1 dill-0.3.6 docker-pycreds-0.4.0 gitdb-4.0.10 gitpython-3.1.31 langdetect-1.0.9 multiprocess-0.70.14 pandas-1.2.4 pathtools-0.1.2 pydeck-0.8.1b0 pympler-1.0.1 rpunct-1.0.2 sentencepiece-0.1.98 sentry-sdk-1.19.1 seqeval-1.2.2 setproctitle-1.3.2 simpletransformers-0.61.4 smmap-5.0.0 streamlit-1.21.0 tensorboardx-2.6 torch-1.8.1 tqdm-4.49.0 validators-0.20.0 wandb-0.14.2 watchdog-3.0.0 xxhash-3.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (4.49.0)

# %%
checkpoint = "sshleifer/distilbart-cnn-12-6"

tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)

# %%
from rpunct import RestorePuncts
# The default language is 'english'
# rpunct = RestorePuncts(use_cuda=False)
rpunct = RestorePuncts()

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# %cd "/content/gdrive/MyDrive/IR_Project_W23"
# Out:
# Mounted at /content/gdrive/
# /content/gdrive/.shortcut-targets-by-id/185mvSLpCVGSaXntfPSeAocQRS6XVVq-_/IR_Project_W23

# %%
def fetch_most_replayed(video_id: str):
  r = requests.get(f'https://yt.lemnoslife.com/videos?part=mostReplayed&id={video_id}')
  if r.status_code != 200:
    raise Exception(f'Error while fetching most replayed for id: {video_id}')
  return json.loads(r.text)['items'][0]['mostReplayed']['heatMarkers']

# %%
fetch_most_replayed('YieuqbIqUps')
# Out:
# [{'heatMarkerRenderer': {'timeRangeStartMillis': 0,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 1}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 2060,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.4254768856939025}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 4120,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.3844264537181312}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 6180,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.3299730038315575}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 8240,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.2926660463058963}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 10300,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.33168912891722424}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 12360,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.33937812522396466}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 14420,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.32314734353015806}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 16480,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.3898350464527254}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 18540,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.3836757862291644}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 20600,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.36659001967883426}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 22660,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.37044907834813845}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 24720,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.33208076899970046}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 26780,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.2692229317219072}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 28840,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.19856893705965914}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 30900,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.17579769399583717}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 32960,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.14911336176971499}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 35020,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.1206053114242384}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 37080,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.12096678658124449}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 39140,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.10671533514618056}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 41200,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.10352595222084585}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 43260,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.08275927284387466}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 45320,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06420453201727867}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 47380,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06710486440380051}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 49440,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.058916311013916214}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 51500,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.04900484722995094}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 53560,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.055536363511685435}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 55620,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.04785499842714031}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 57680,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.03943347678231244}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 59740,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05785465322232497}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 61800,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.04937382762199346}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 63860,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.04629673525155622}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 65920,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.054880546355193294}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 67980,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05043714124481576}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 70040,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05624154963629487}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 72100,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.03632038808076526}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 74160,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.03904286259527284}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 76220,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.03530325775075701}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 78280,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.053647204062373145}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 80340,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05257930090733432}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 82400,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.09815612753485714}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 84460,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.12540639407868992}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 86520,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.13230174327711822}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 88580,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.13761512571592652}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 90640,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.19527728855764104}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 92700,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.2315816042765657}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 94760,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.24929478687814224}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 96820,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.4560522413313545}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 98880,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.47152202458916576}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 100940,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.5158605774265064}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 103000,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.5362699932172114}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 105060,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.6000278467617467}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 107120,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.4759973044507412}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 109180,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.319999104411282}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 111240,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.24156864235769634}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 113300,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.2113756397492942}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 115360,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.14600248684253106}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 117420,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.09514154279339232}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 119480,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.09377375420387653}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 121540,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.08052195688006696}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 123600,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06807989702457566}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 125660,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.08168381045930274}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 127720,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.0768678253237717}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 129780,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.09591103636352968}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 131840,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.0886571637072463}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 133900,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.07439237563150614}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 135960,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06680712075102457}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 138020,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.07767295526170791}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 140080,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06580077132218376}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 142140,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.07173402858087093}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 144200,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06684479091153113}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 146260,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05549754146858336}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 148320,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05811949622846641}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 150380,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05033658549386012}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 152440,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.04124056459669405}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 154500,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.056937754676292376}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 156560,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05746936649228964}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 158620,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.054133172530523}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 160680,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.09344269594665833}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 162740,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.10168229213405652}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 164800,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.11103874648680308}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 166860,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.15001247812817925}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 168920,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.15239377941642676}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 170980,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.14485438386177926}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 173040,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.12845719112925133}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 175100,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.08840234567931898}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 177160,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05666702627001446}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 179220,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.056597085398667826}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 181280,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.05848460701491461}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 183340,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.055108943076085916}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 185400,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.04443082943214096}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 187460,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.0631058699973064}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 189520,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.07586572346200186}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 191580,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.07970714392906217}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 193640,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.08331430027325895}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 195700,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.09349334278453003}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 197760,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.08354701655388476}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 199820,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.06520769577081625}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 201880,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0.032283741511930135}},
#  {'heatMarkerRenderer': {'timeRangeStartMillis': 203940,
#    'markerDurationMillis': 2060,
#    'heatMarkerIntensityScoreNormalized': 0}}]

# %%
def fetch_captions(video_id: str, languages=['en']):
  return YouTubeTranscriptApi.get_transcript(video_id, languages=languages)

# %%
fetch_captions('YieuqbIqUps')
# Out:
# [{'text': 'sugar is okay for you know yes thank you',
#   'start': 0.16,
#   'duration': 6.8},
#  {'text': 'how are you miss kulkarni how i am i am',
#   'start': 3.28,
#   'duration': 5.6},
#  {'text': 'worried like all other mothers', 'start': 6.96, 'duration': 6.0},
#  {'text': 'everywhere all the time we are worried',
#   'start': 8.88,
#   'duration': 8.08},
#  {'text': 'your i am fine is my', 'start': 12.96, 'duration': 4.0},
#  {'text': 'ass toy means toy gun', 'start': 29.119, 'duration': 5.28},
#  {'text': 'it is not making any why we are doing do',
#   'start': 32.48,
#   'duration': 3.919},
#  {'text': 'you have to stop this', 'start': 34.399, 'duration': 4.641},
#  {'text': 'see last year my papa gave pratibha',
#   'start': 36.399,
#   'duration': 4.16},
#  {'text': 'kitchen set', 'start': 39.04, 'duration': 4.08},
#  {'text': 'my husband got so upset just because',
#   'start': 40.559,
#   'duration': 4.401},
#  {'text': "she's girl you are giving her kitchen",
#   'start': 43.12,
#   'duration': 2.72},
#  {'text': 'set', 'start': 44.96, 'duration': 3.36},
#  {'text': 'name but i understand but what', 'start': 45.84, 'duration': 5.199},
#  {'text': "prativha's papa has given pratibha",
#   'start': 48.32,
#   'duration': 5.28},
#  {'text': 'gun did you ask him why he got the gun i',
#   'start': 51.039,
#   'duration': 4.481},
#  {'text': "asked him he's telling no one day",
#   'start': 53.6,
#   'duration': 5.439},
#  {'text': 'pratibha is going to become soldier huh',
#   'start': 55.52,
#   'duration': 5.12},
#  {'text': 'that is why now she has to play with',
#   'start': 59.039,
#   'duration': 2.721},
#  {'text': 'tygan', 'start': 60.64, 'duration': 3.36},
#  {'text': 'that means children who are one day',
#   'start': 61.76,
#   'duration': 4.399},
#  {'text': 'going to become charter accountant are',
#   'start': 64.0,
#   'duration': 5.6},
#  {'text': 'now playing with toy calculator',
#   'start': 66.159,
#   'duration': 5.201},
#  {'text': 'so have you asked prativa if she wants',
#   'start': 69.6,
#   'duration': 4.4},
#  {'text': 'to be a soldier that day she got the toy',
#   'start': 71.36,
#   'duration': 5.52},
#  {'text': 'gun pratibha decided she is going to be',
#   'start': 74.0,
#   'duration': 5.84},
#  {'text': 'shikari shambo shikari shambhu you know',
#   'start': 76.88,
#   'duration': 4.4},
#  {'text': 'comics', 'start': 79.84, 'duration': 3.279},
#  {'text': 'both are same shikhari shampoo and my',
#   'start': 81.28,
#   'duration': 2.879},
#  {'text': 'protiba', 'start': 83.119, 'duration': 4.081},
#  {'text': 'lazy liars telling tall stories all the',
#   'start': 84.159,
#   'duration': 5.761},
#  {'text': 'time and now she also has gun she curry',
#   'start': 87.2,
#   'duration': 5.44},
#  {'text': 'shambo soldier whatever', 'start': 89.92, 'duration': 4.72},
#  {'text': 'summer holidays are on the corner what',
#   'start': 92.64,
#   'duration': 3.6},
#  {'text': 'holiday plans', 'start': 94.64, 'duration': 4.12},
#  {'text': 'yes summer holidays', 'start': 96.24, 'duration': 5.639},
#  {'text': '[Music]', 'start': 98.76, 'duration': 3.119},
#  {'text': "and come back that's all sum up the",
#   'start': 112.479,
#   'duration': 4.0},
#  {'text': 'summer holidays are you not enrolling',
#   'start': 114.64,
#   'duration': 4.079},
#  {'text': 'pratibha in any hobby classes coding is',
#   'start': 116.479,
#   'duration': 4.161},
#  {'text': 'very popular these days', 'start': 118.719, 'duration': 2.801},
#  {'text': 'oh', 'start': 120.64, 'duration': 2.88},
#  {'text': 'computer coding', 'start': 121.52, 'duration': 3.599},
#  {'text': 'programmer', 'start': 123.52, 'duration': 4.08},
#  {'text': 'means then they should have mini mbbs',
#   'start': 125.119,
#   'duration': 6.641},
#  {'text': 'and junior is officer course also no',
#   'start': 127.6,
#   'duration': 5.68},
#  {'text': 'code audio', 'start': 131.76, 'duration': 3.6},
#  {'text': 'maishikari shambu for last one year has',
#   'start': 133.28,
#   'duration': 4.4},
#  {'text': 'not been able to decode multiplication',
#   'start': 135.36,
#   'duration': 3.599},
#  {'text': 'and division', 'start': 137.68, 'duration': 5.52},
#  {'text': 'that the teacher is asking pratibha',
#   'start': 138.959,
#   'duration': 4.241},
#  {'text': 'teacher has not asked what do you want',
#   'start': 148.48,
#   'duration': 3.44},
#  {'text': 'to have nasta', 'start': 150.319, 'duration': 4.481},
#  {'text': 'teacher is asking multiplication tables',
#   'start': 151.92,
#   'duration': 5.92},
#  {'text': 'but my pratibha knows only one table',
#   'start': 154.8,
#   'duration': 4.719},
#  {'text': 'dining table', 'start': 157.84, 'duration': 4.64},
#  {'text': "breakfast lunch dinner so she's thinking",
#   'start': 159.519,
#   'duration': 6.841},
#  {'text': 'when i have written multiplication',
#   'start': 162.48,
#   'duration': 3.88},
#  {'text': '6 times 7 is 30.', 'start': 171.12, 'duration': 5.839},
#  {'text': 'i want to apologize to maths teacher in',
#   'start': 173.92,
#   'duration': 5.679},
#  {'text': 'third standard of bulbul vidya mandir he',
#   'start': 176.959,
#   'duration': 4.481},
#  {'text': 'is going to third standard next year',
#   'start': 179.599,
#   'duration': 4.321},
#  {'text': 'teacher please i am sorry samhalin',
#   'start': 181.44,
#   'duration': 3.36},
#  {'text': 'and', 'start': 183.92, 'duration': 3.679},
#  {'text': 'our indian army should enroll my',
#   'start': 184.8,
#   'duration': 5.92},
#  {'text': 'pratibha if ever they have to fight a',
#   'start': 187.599,
#   'duration': 5.601},
#  {'text': 'war against mathematics', 'start': 190.72, 'duration': 4.879},
#  {'text': 'because that is her number any one enemy',
#   'start': 193.2,
#   'duration': 5.959},
#  {'text': 'she will fight properly', 'start': 195.599, 'duration': 3.56},
#  {'text': 'two', 'start': 201.44, 'duration': 4.68},
#  {'text': 'six sevens are thirty', 'start': 202.4, 'duration': 3.72}]

# %%
def remove_caption_overlaps(captions: list):
  for i in range(len(captions) - 1):
    captions[i]['duration'] = min(captions[i]['duration'], captions[i + 1]['start'] - captions[i]['start'])
  return captions

# %%
remove_caption_overlaps(fetch_captions('YieuqbIqUps'))
# Out:
# [{'text': 'sugar is okay for you know yes thank you',
#   'start': 0.16,
#   'duration': 3.1199999999999997},
#  {'text': 'how are you miss kulkarni how i am i am',
#   'start': 3.28,
#   'duration': 3.68},
#  {'text': 'worried like all other mothers',
#   'start': 6.96,
#   'duration': 1.9200000000000008},
#  {'text': 'everywhere all the time we are worried',
#   'start': 8.88,
#   'duration': 4.08},
#  {'text': 'your i am fine is my', 'start': 12.96, 'duration': 4.0},
#  {'text': 'ass toy means toy gun',
#   'start': 29.119,
#   'duration': 3.360999999999997},
#  {'text': 'it is not making any why we are doing do',
#   'start': 32.48,
#   'duration': 1.919000000000004},
#  {'text': 'you have to stop this', 'start': 34.399, 'duration': 2.0},
#  {'text': 'see last year my papa gave pratibha',
#   'start': 36.399,
#   'duration': 2.6409999999999982},
#  {'text': 'kitchen set', 'start': 39.04, 'duration': 1.5189999999999984},
#  {'text': 'my husband got so upset just because',
#   'start': 40.559,
#   'duration': 2.561},
#  {'text': "she's girl you are giving her kitchen",
#   'start': 43.12,
#   'duration': 1.8400000000000034},
#  {'text': 'set', 'start': 44.96, 'duration': 0.8800000000000026},
#  {'text': 'name but i understand but what',
#   'start': 45.84,
#   'duration': 2.479999999999997},
#  {'text': "prativha's papa has given pratibha",
#   'start': 48.32,
#   'duration': 2.719000000000001},
#  {'text': 'gun did you ask him why he got the gun i',
#   'start': 51.039,
#   'duration': 2.561},
#  {'text': "asked him he's telling no one day",
#   'start': 53.6,
#   'duration': 1.9200000000000017},
#  {'text': 'pratibha is going to become soldier huh',
#   'start': 55.52,
#   'duration': 3.5189999999999984},
#  {'text': 'that is why now she has to play with',
#   'start': 59.039,
#   'duration': 1.600999999999999},
#  {'text': 'tygan', 'start': 60.64, 'duration': 1.1199999999999974},
#  {'text': 'that means children who are one day',
#   'start': 61.76,
#   'duration': 2.240000000000002},
#  {'text': 'going to become charter accountant are',
#   'start': 64.0,
#   'duration': 2.159000000000006},
#  {'text': 'now playing with toy calculator',
#   'start': 66.159,
#   'duration': 3.4409999999999883},
#  {'text': 'so have you asked prativa if she wants',
#   'start': 69.6,
#   'duration': 1.7600000000000051},
#  {'text': 'to be a soldier that day she got the toy',
#   'start': 71.36,
#   'duration': 2.6400000000000006},
#  {'text': 'gun pratibha decided she is going to be',
#   'start': 74.0,
#   'duration': 2.8799999999999955},
#  {'text': 'shikari shambo shikari shambhu you know',
#   'start': 76.88,
#   'duration': 2.960000000000008},
#  {'text': 'comics', 'start': 79.84, 'duration': 1.4399999999999977},
#  {'text': 'both are same shikhari shampoo and my',
#   'start': 81.28,
#   'duration': 1.8389999999999986},
#  {'text': 'protiba', 'start': 83.119, 'duration': 1.0400000000000063},
#  {'text': 'lazy liars telling tall stories all the',
#   'start': 84.159,
#   'duration': 3.040999999999997},
#  {'text': 'time and now she also has gun she curry',
#   'start': 87.2,
#   'duration': 2.719999999999999},
#  {'text': 'shambo soldier whatever',
#   'start': 89.92,
#   'duration': 2.719999999999999},
#  {'text': 'summer holidays are on the corner what',
#   'start': 92.64,
#   'duration': 2.0},
#  {'text': 'holiday plans', 'start': 94.64, 'duration': 1.5999999999999943},
#  {'text': 'yes summer holidays',
#   'start': 96.24,
#   'duration': 2.5200000000000102},
#  {'text': '[Music]', 'start': 98.76, 'duration': 3.119},
#  {'text': "and come back that's all sum up the",
#   'start': 112.479,
#   'duration': 2.1610000000000014},
#  {'text': 'summer holidays are you not enrolling',
#   'start': 114.64,
#   'duration': 1.8389999999999986},
#  {'text': 'pratibha in any hobby classes coding is',
#   'start': 116.479,
#   'duration': 2.239999999999995},
#  {'text': 'very popular these days',
#   'start': 118.719,
#   'duration': 1.9210000000000065},
#  {'text': 'oh', 'start': 120.64, 'duration': 0.8799999999999955},
#  {'text': 'computer coding', 'start': 121.52, 'duration': 2.0},
#  {'text': 'programmer', 'start': 123.52, 'duration': 1.5990000000000038},
#  {'text': 'means then they should have mini mbbs',
#   'start': 125.119,
#   'duration': 2.4809999999999945},
#  {'text': 'and junior is officer course also no',
#   'start': 127.6,
#   'duration': 4.159999999999997},
#  {'text': 'code audio', 'start': 131.76, 'duration': 1.5200000000000102},
#  {'text': 'maishikari shambu for last one year has',
#   'start': 133.28,
#   'duration': 2.0800000000000125},
#  {'text': 'not been able to decode multiplication',
#   'start': 135.36,
#   'duration': 2.319999999999993},
#  {'text': 'and division', 'start': 137.68, 'duration': 1.2789999999999964},
#  {'text': 'that the teacher is asking pratibha',
#   'start': 138.959,
#   'duration': 4.241},
#  {'text': 'teacher has not asked what do you want',
#   'start': 148.48,
#   'duration': 1.8389999999999986},
#  {'text': 'to have nasta', 'start': 150.319, 'duration': 1.600999999999999},
#  {'text': 'teacher is asking multiplication tables',
#   'start': 151.92,
#   'duration': 2.880000000000024},
#  {'text': 'but my pratibha knows only one table',
#   'start': 154.8,
#   'duration': 3.039999999999992},
#  {'text': 'dining table', 'start': 157.84, 'duration': 1.679000000000002},
#  {'text': "breakfast lunch dinner so she's thinking",
#   'start': 159.519,
#   'duration': 2.9609999999999843},
#  {'text': 'when i have written multiplication',
#   'start': 162.48,
#   'duration': 3.88},
#  {'text': '6 times 7 is 30.', 'start': 171.12, 'duration': 2.799999999999983},
#  {'text': 'i want to apologize to maths teacher in',
#   'start': 173.92,
#   'duration': 3.0390000000000157},
#  {'text': 'third standard of bulbul vidya mandir he',
#   'start': 176.959,
#   'duration': 2.6399999999999864},
#  {'text': 'is going to third standard next year',
#   'start': 179.599,
#   'duration': 1.8410000000000082},
#  {'text': 'teacher please i am sorry samhalin',
#   'start': 181.44,
#   'duration': 2.4799999999999898},
#  {'text': 'and', 'start': 183.92, 'duration': 0.8800000000000239},
#  {'text': 'our indian army should enroll my',
#   'start': 184.8,
#   'duration': 2.798999999999978},
#  {'text': 'pratibha if ever they have to fight a',
#   'start': 187.599,
#   'duration': 3.1210000000000093},
#  {'text': 'war against mathematics',
#   'start': 190.72,
#   'duration': 2.4799999999999898},
#  {'text': 'because that is her number any one enemy',
#   'start': 193.2,
#   'duration': 2.399000000000001},
#  {'text': 'she will fight properly', 'start': 195.599, 'duration': 3.56},
#  {'text': 'two', 'start': 201.44, 'duration': 0.960000000000008},
#  {'text': 'six sevens are thirty', 'start': 202.4, 'duration': 3.72}]

# %%
def fuse_captions_most_replayed(captions: list, most_replayed: list):
  # ind for iterating over most_replayed
  ind = 0
  n = len(most_replayed)

  for caption in captions:
    end_dur = caption['start'] + caption['duration']
    intensity = 0
    count = 0

    while ind < n and most_replayed[ind]['heatMarkerRenderer']['timeRangeStartMillis'] / 1000 < caption['start']:
      ind += 1
    
    while ind < n and most_replayed[ind]['heatMarkerRenderer']['timeRangeStartMillis'] / 1000 < end_dur:
      intensity += most_replayed[ind]['heatMarkerRenderer']['heatMarkerIntensityScoreNormalized']
      count += 1
      ind += 1
    
    if count:
      intensity = intensity / count

    caption['intensity'] = intensity
  return captions

# %%
def get_fused_captions_intensity(video_id: str):
  most_replayed = fetch_most_replayed(video_id)
  captions = fetch_captions(video_id)
  remove_caption_overlaps(captions)
  return fuse_captions_most_replayed(captions, most_replayed)

# %%
get_fused_captions_intensity('YieuqbIqUps')
# Out:
# [{'text': 'sugar is okay for you know yes thank you',
#   'start': 0.16,
#   'duration': 3.1199999999999997,
#   'intensity': 0.4254768856939025},
#  {'text': 'how are you miss kulkarni how i am i am',
#   'start': 3.28,
#   'duration': 3.68,
#   'intensity': 0.35719972877484435},
#  {'text': 'worried like all other mothers',
#   'start': 6.96,
#   'duration': 1.9200000000000008,
#   'intensity': 0.2926660463058963},
#  {'text': 'everywhere all the time we are worried',
#   'start': 8.88,
#   'duration': 4.08,
#   'intensity': 0.3355336270705944},
#  {'text': 'your i am fine is my',
#   'start': 12.96,
#   'duration': 4.0,
#   'intensity': 0.3564911949914417},
#  {'text': 'ass toy means toy gun',
#   'start': 29.119,
#   'duration': 3.360999999999997,
#   'intensity': 0.17579769399583717},
#  {'text': 'it is not making any why we are doing do',
#   'start': 32.48,
#   'duration': 1.919000000000004,
#   'intensity': 0.14911336176971499},
#  {'text': 'you have to stop this',
#   'start': 34.399,
#   'duration': 2.0,
#   'intensity': 0.1206053114242384},
#  {'text': 'see last year my papa gave pratibha',
#   'start': 36.399,
#   'duration': 2.6409999999999982,
#   'intensity': 0.12096678658124449},
#  {'text': 'kitchen set',
#   'start': 39.04,
#   'duration': 1.5189999999999984,
#   'intensity': 0.10671533514618056},
#  {'text': 'my husband got so upset just because',
#   'start': 40.559,
#   'duration': 2.561,
#   'intensity': 0.10352595222084585},
#  {'text': "she's girl you are giving her kitchen",
#   'start': 43.12,
#   'duration': 1.8400000000000034,
#   'intensity': 0.08275927284387466},
#  {'text': 'set',
#   'start': 44.96,
#   'duration': 0.8800000000000026,
#   'intensity': 0.06420453201727867},
#  {'text': 'name but i understand but what',
#   'start': 45.84,
#   'duration': 2.479999999999997,
#   'intensity': 0.06710486440380051},
#  {'text': "prativha's papa has given pratibha",
#   'start': 48.32,
#   'duration': 2.719000000000001,
#   'intensity': 0.058916311013916214},
#  {'text': 'gun did you ask him why he got the gun i',
#   'start': 51.039,
#   'duration': 2.561,
#   'intensity': 0.052270605370818186},
#  {'text': "asked him he's telling no one day",
#   'start': 53.6,
#   'duration': 1.9200000000000017,
#   'intensity': 0},
#  {'text': 'pratibha is going to become soldier huh',
#   'start': 55.52,
#   'duration': 3.5189999999999984,
#   'intensity': 0.043644237604726376},
#  {'text': 'that is why now she has to play with',
#   'start': 59.039,
#   'duration': 1.600999999999999,
#   'intensity': 0.05785465322232497},
#  {'text': 'tygan',
#   'start': 60.64,
#   'duration': 1.1199999999999974,
#   'intensity': 0},
#  {'text': 'that means children who are one day',
#   'start': 61.76,
#   'duration': 2.240000000000002,
#   'intensity': 0.04783528143677484},
#  {'text': 'going to become charter accountant are',
#   'start': 64.0,
#   'duration': 2.159000000000006,
#   'intensity': 0.054880546355193294},
#  {'text': 'now playing with toy calculator',
#   'start': 66.159,
#   'duration': 3.4409999999999883,
#   'intensity': 0.05043714124481576},
#  {'text': 'so have you asked prativa if she wants',
#   'start': 69.6,
#   'duration': 1.7600000000000051,
#   'intensity': 0.05624154963629487},
#  {'text': 'to be a soldier that day she got the toy',
#   'start': 71.36,
#   'duration': 2.6400000000000006,
#   'intensity': 0.03632038808076526},
#  {'text': 'gun pratibha decided she is going to be',
#   'start': 74.0,
#   'duration': 2.8799999999999955,
#   'intensity': 0.03717306017301493},
#  {'text': 'shikari shambo shikari shambhu you know',
#   'start': 76.88,
#   'duration': 2.960000000000008,
#   'intensity': 0.053647204062373145},
#  {'text': 'comics',
#   'start': 79.84,
#   'duration': 1.4399999999999977,
#   'intensity': 0.05257930090733432},
#  {'text': 'both are same shikhari shampoo and my',
#   'start': 81.28,
#   'duration': 1.8389999999999986,
#   'intensity': 0.09815612753485714},
#  {'text': 'protiba',
#   'start': 83.119,
#   'duration': 1.0400000000000063,
#   'intensity': 0},
#  {'text': 'lazy liars telling tall stories all the',
#   'start': 84.159,
#   'duration': 3.040999999999997,
#   'intensity': 0.12885406867790405},
#  {'text': 'time and now she also has gun she curry',
#   'start': 87.2,
#   'duration': 2.719999999999999,
#   'intensity': 0.13761512571592652},
#  {'text': 'shambo soldier whatever',
#   'start': 89.92,
#   'duration': 2.719999999999999,
#   'intensity': 0.19527728855764104},
#  {'text': 'summer holidays are on the corner what',
#   'start': 92.64,
#   'duration': 2.0,
#   'intensity': 0.2315816042765657},
#  {'text': 'holiday plans',
#   'start': 94.64,
#   'duration': 1.5999999999999943,
#   'intensity': 0.24929478687814224},
#  {'text': 'yes summer holidays',
#   'start': 96.24,
#   'duration': 2.5200000000000102,
#   'intensity': 0.4560522413313545},
#  {'text': '[Music]',
#   'start': 98.76,
#   'duration': 3.119,
#   'intensity': 0.4936913010078361},
#  {'text': "and come back that's all sum up the",
#   'start': 112.479,
#   'duration': 2.1610000000000014,
#   'intensity': 0.2113756397492942},
#  {'text': 'summer holidays are you not enrolling',
#   'start': 114.64,
#   'duration': 1.8389999999999986,
#   'intensity': 0.14600248684253106},
#  {'text': 'pratibha in any hobby classes coding is',
#   'start': 116.479,
#   'duration': 2.239999999999995,
#   'intensity': 0.09514154279339232},
#  {'text': 'very popular these days',
#   'start': 118.719,
#   'duration': 1.9210000000000065,
#   'intensity': 0.09377375420387653},
#  {'text': 'oh',
#   'start': 120.64,
#   'duration': 0.8799999999999955,
#   'intensity': 0},
#  {'text': 'computer coding',
#   'start': 121.52,
#   'duration': 2.0,
#   'intensity': 0.08052195688006696},
#  {'text': 'programmer',
#   'start': 123.52,
#   'duration': 1.5990000000000038,
#   'intensity': 0.06807989702457566},
#  {'text': 'means then they should have mini mbbs',
#   'start': 125.119,
#   'duration': 2.4809999999999945,
#   'intensity': 0.08168381045930274},
#  {'text': 'and junior is officer course also no',
#   'start': 127.6,
#   'duration': 4.159999999999997,
#   'intensity': 0.0863894308436507},
#  {'text': 'code audio',
#   'start': 131.76,
#   'duration': 1.5200000000000102,
#   'intensity': 0.0886571637072463},
#  {'text': 'maishikari shambu for last one year has',
#   'start': 133.28,
#   'duration': 2.0800000000000125,
#   'intensity': 0.07439237563150614},
#  {'text': 'not been able to decode multiplication',
#   'start': 135.36,
#   'duration': 2.319999999999993,
#   'intensity': 0.06680712075102457},
#  {'text': 'and division',
#   'start': 137.68,
#   'duration': 1.2789999999999964,
#   'intensity': 0.07767295526170791},
#  {'text': 'that the teacher is asking pratibha',
#   'start': 138.959,
#   'duration': 4.241,
#   'intensity': 0.06876739995152734},
#  {'text': 'teacher has not asked what do you want',
#   'start': 148.48,
#   'duration': 1.8389999999999986,
#   'intensity': 0},
#  {'text': 'to have nasta',
#   'start': 150.319,
#   'duration': 1.600999999999999,
#   'intensity': 0.05033658549386012},
#  {'text': 'teacher is asking multiplication tables',
#   'start': 151.92,
#   'duration': 2.880000000000024,
#   'intensity': 0.04908915963649321},
#  {'text': 'but my pratibha knows only one table',
#   'start': 154.8,
#   'duration': 3.039999999999992,
#   'intensity': 0.05746936649228964},
#  {'text': 'dining table',
#   'start': 157.84,
#   'duration': 1.679000000000002,
#   'intensity': 0.054133172530523},
#  {'text': "breakfast lunch dinner so she's thinking",
#   'start': 159.519,
#   'duration': 2.9609999999999843,
#   'intensity': 0.09344269594665833},
#  {'text': 'when i have written multiplication',
#   'start': 162.48,
#   'duration': 3.88,
#   'intensity': 0.10636051931042981},
#  {'text': '6 times 7 is 30.',
#   'start': 171.12,
#   'duration': 2.799999999999983,
#   'intensity': 0.12845719112925133},
#  {'text': 'i want to apologize to maths teacher in',
#   'start': 173.92,
#   'duration': 3.0390000000000157,
#   'intensity': 0.08840234567931898},
#  {'text': 'third standard of bulbul vidya mandir he',
#   'start': 176.959,
#   'duration': 2.6399999999999864,
#   'intensity': 0.05663205583434114},
#  {'text': 'is going to third standard next year',
#   'start': 179.599,
#   'duration': 1.8410000000000082,
#   'intensity': 0.05848460701491461},
#  {'text': 'teacher please i am sorry samhalin',
#   'start': 181.44,
#   'duration': 2.4799999999999898,
#   'intensity': 0.055108943076085916},
#  {'text': 'and',
#   'start': 183.92,
#   'duration': 0.8800000000000239,
#   'intensity': 0},
#  {'text': 'our indian army should enroll my',
#   'start': 184.8,
#   'duration': 2.798999999999978,
#   'intensity': 0.053768349714723676},
#  {'text': 'pratibha if ever they have to fight a',
#   'start': 187.599,
#   'duration': 3.1210000000000093,
#   'intensity': 0.07586572346200186},
#  {'text': 'war against mathematics',
#   'start': 190.72,
#   'duration': 2.4799999999999898,
#   'intensity': 0.07970714392906217},
#  {'text': 'because that is her number any one enemy',
#   'start': 193.2,
#   'duration': 2.399000000000001,
#   'intensity': 0.08331430027325895},
#  {'text': 'she will fight properly',
#   'start': 195.599,
#   'duration': 3.56,
#   'intensity': 0.08852017966920739},
#  {'text': 'two',
#   'start': 201.44,
#   'duration': 0.960000000000008,
#   'intensity': 0.032283741511930135},
#  {'text': 'six sevens are thirty',
#   'start': 202.4,
#   'duration': 3.72,
#   'intensity': 0.0}]

# %%
import nltk
nltk.download('punkt')
def str_to_sentences(string_data: str):
  return nltk.tokenize.sent_tokenize(string_data)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def create_chunks(sentences: list):
  # initialize
  length = 0
  chunk = ""
  chunks = []
  count = -1
  for sentence in sentences:
    count += 1
    combined_length = len(tokenizer.tokenize(sentence)) + length # add the no. of sentence tokens to the length counter

    if combined_length  <= tokenizer.max_len_single_sentence: # if it doesn't exceed
      chunk += sentence + " " # add the sentence to the chunk
      length = combined_length # update the length counter

      # if it is the last sentence
      if count == len(sentences) - 1:
        chunks.append(chunk.strip()) # save the chunk
      
    else: 
      chunks.append(chunk.strip()) # save the chunk
      
      # reset 
      length = 0 
      chunk = ""

      # take care of the overflow sentence
      chunk += sentence + " "
      length = len(tokenizer.tokenize(sentence))
  return chunks

# %%
def summary(chunks):
  inputs = [tokenizer(chunk, return_tensors="pt") for chunk in chunks]
  outputs = ''
  for input in inputs:
    output = model.generate(**input)
    outputs += tokenizer.decode(*output, skip_special_tokens=True)
  return outputs

# %%
def get_summary(long_string: str):
  sents = str_to_sentences(long_string)
  chunks = create_chunks(sents)
  summ = summary(chunks)
  return summ

# %%
def process_video_list(video_ids: list, filepath: str):
  result = []
  for id in tqdm(video_ids):
    try:
      fused_captions = get_fused_captions_intensity(id)
      text_captions = ' '.join([caption['text'] for caption in fused_captions])
      ARTICLE = rpunct.punctuate(text_captions)
      summary = get_summary(ARTICLE)

    except:
      continue

    result.append({
        'id': id,
        'text_captions': ARTICLE,
        'fused_captions': fused_captions,
        'summary': summary
    })

  # Serializing json
  json_object = json.dumps(result, indent=4)
  
  # Writing to sample.json
  with open(filepath, "w") as outfile:
      outfile.write(json_object)

# %%
cnn10_video_ids = [
    '8GgaCgjAFLM',
    'Kc_GMYHJNFQ',
    'wPdiuj2JwEU',
    'H07TJT3VpSY',
    'U4WxR7hXfCQ',
    '1xbEbTJASoE',
    'rQp4putiL_A',
    'rQp4putiL_A',
    '94N_3jBAU_c',
    'owDr-ra0P6I'
]
# process_video_list(cnn10_video_ids, 'data/cnn10.json')

# %%
def fetch_channelID_from_username(username: str):
  r = requests.get(f'https://yt.lemnoslife.com/noKey/channels?forUsername={username}&part=id')
  if r.status_code != 200 or 'items' not in json.loads(r.text).keys():
    raise Exception(f'Error while fetching channel ID for username: {username}')
  return json.loads(r.text)['items'][0]['id']

# %%
def fetch_videos_for_channelID(channelID: str, maxResults: int):
  ans = []
  pageToken = ''
  while(len(ans) < maxResults):
    link = f'https://yt.lemnoslife.com/noKey/search?channelId={channelID}&part=id&order=date&maxResults={maxResults}'
    if pageToken:
      link += f'&pageToken={pageToken}'
    r = requests.get(link)
    if r.status_code != 200 or 'items' not in json.loads(r.text).keys():
      raise Exception(f'Error while fetching videoes for channelID: {channelID}')
    
    json_obj = json.loads(r.text)
    
    if len(json_obj['items']) == 0:
      break

    for item in json_obj['items']:
      if 'videoId' in item['id'].keys():
        ans.append(item['id']['videoId'])

    if 'nextPageToken' in json_obj.keys():
      pageToken = json_obj['nextPageToken']
    else:
      break
  return ans

# %%
c_id = fetch_channelID_from_username('dhruvrathee')
fetch_videos_for_channelID(c_id, 1000)
# Out:
# ['p9ju0x3xVCA',
#  'D-iPbtcxgM8',
#  'wvhhuZWwZnA',
#  'sDEZSFNQmP0',
#  '-iDMd0JHYXc',
#  'Y-k2eaDcyqo',
#  'zMZ6IBCQCm8',
#  'CFZWI8ExfuY',
#  'vb1GIHNY4OE',
#  'L1UC_bnCk8k',
#  'Hu-Bdubnnj0',
#  'ueUyKgO079I',
#  '7RuNk6L9ekk',
#  '3cvag-9tCW0',
#  '1unoB93xeeQ',
#  'R1gTM30ZRkM',
#  'c1YmChaP01g',
#  'NoxkNvz6Dqo',
#  'DUel5IzusKc',
#  'JILyj5IZ3rI',
#  'byC5e6X9q80',
#  'j0lm6JIfD38',
#  'hVvAkPbJwnw',
#  'mTrsShdSNKg',
#  '8VKnGdl4Q3U',
#  'MJ_vmdIJIRw',
#  'CFGG-mFZBHo',
#  'Vh6n-0B29aw',
#  'YrEwBEqYohM',
#  '85SAO5HYrjc',
#  'Aesag8J7EeM',
#  '1fuau2Idip8',
#  'YcMEQtxBH6k',
#  'y_isRZIrAUQ',
#  'Hmhp1ZYPC5w',
#  'vXVRs_Sar6Y',
#  '5iy4p_bYu5Q',
#  'TTGczb8uLA0',
#  'RPiXj1t4wRQ',
#  'bJHEPmu837Y',
#  'q0PbcaBgmWk',
#  '1CR3hS5Y-PI',
#  'X50iFxhUWiU',
#  'xIEzhdj5G5k',
#  '3bZoB8PiXas',
#  'Lr7GMr1NzV0',
#  'mX3ZWEG9lyw',
#  '5No-IWBTBaQ',
#  'qlMBNrY7ABo',
#  'd0KuhikVnVs',
#  'JE22hiUR2dI',
#  'oqC5mg2k4Tk',
#  'b8n-wpvBjrw',
#  'JWgwHjfhA3A',
#  't_cSk9tQQkk',
#  '85nMXO_nRxc',
#  'Ih_4C6DJ0EU',
#  'ji1fQRWJqlc',
#  'vh9rBp_4eHU',
#  'HvWlcpf48x4',
#  'TGHqBX1YJRc',
#  'wQhiQrt2TqQ',
#  'w6l4Gsqgi9U',
#  'tMsf6i7yID8',
#  '-05P5FB4AJc',
#  'Iwz_Vdz8EKw',
#  'ZuKJpVNUHGg',
#  '5UmJwPivCHE',
#  'SRIooZz0bSI',
#  'pH5uKjcP5GE',
#  'y7zrjWp3fEk',
#  'id00R-3OmJ0',
#  '4DhK260KYzQ',
#  'hdBUo3P-sU8',
#  'bJj8XEw-zCg',
#  '_6M4rX-PYzs',
#  '_xVi4j5A-go',
#  'j9VOQZX5btA',
#  'HzH71M5plAs',
#  'LwMutPnXnoA',
#  'IFxmKHhZnPE',
#  'nxvw_O3IBow',
#  'klnYxLLcceE',
#  'LLw-T_d-wWo',
#  'mmz67ouBhF4',
#  'BkU4o3vPxwY',
#  'pGzmmjDDHJg',
#  'CepJaH711bs',
#  'IYkpHNTF0dU',
#  '52ElK1Wdalo',
#  'rDqemu6oisc',
#  '4JGw68lzRM8',
#  'WEnaBfzu-ec',
#  'nnlyR5EdbIA',
#  'biMWZnXGA3I',
#  '92pqF6EYEqc',
#  'RguM2VAg44w',
#  'v4rWJESPWB0',
#  'yBT3hULVhjc',
#  'npCZW5LhUKs',
#  'npCZW5LhUKs',
#  'CAwokHvMFlY',
#  'd7gxZOQZfWQ',
#  'r2ujSeOqulg',
#  '890wWM0lg94',
#  '8q4lqGiJEkI',
#  'sxrxE9QByH0',
#  '0azMpBagjI4',
#  'Ajh1xjop_6w',
#  'UTwtK-H1_A0',
#  'aXgu3-n_78Y',
#  'B1ogwWZxCzk',
#  'mcdIV1eWjJg',
#  'XtBbJKuyKLw',
#  'leIiFgI79Ek',
#  '0r8l5JI8rOM',
#  'prrgCqv576c',
#  'LXHeGwHvHEc',
#  'q5t1yfdO2_8',
#  'kISNb115Lz4',
#  'F2S_4AkECJQ',
#  'Nm0WSJUv4Fw',
#  'ARQMEP6SH14',
#  '6-Q3JQ0gUcs',
#  'l11_-f6D-XA',
#  'ZFkAkN5T8_0',
#  'zn0XD7HBs9s',
#  'dlmg5jNV8Hg',
#  'IjRR1JycSaM',
#  'nxOp4ilK550',
#  'Swm72ewthlM',
#  'hEOjrfecaRk',
#  'vTFd0_SUeEc',
#  'Rym2dd1brE4',
#  '3gz3oYT9tFk',
#  'jWYUnmgQZfk',
#  'H0hy2QTqNuU',
#  'OH2--jzeZ9k',
#  'fpLAWWTJFag',
#  'TiHT3EOgirg',
#  'fp21Pmt1H-Y',
#  'YeC4clsQbIo',
#  'vT7OYzyoAwI',
#  'Z-tMp5-33k0',
#  'zl4LqMZ139Y',
#  'lalOwOl2FAA',
#  'qpHWsIXNIRY',
#  'rO9VEY5tQlY',
#  'pbr4-Thu1Lw',
#  'gYWXC3vQ1rs',
#  'yoIvGRuA00s',
#  'nw-84LXi7Go',
#  '5WmBt6BBUzs',
#  'HvZDi-YzPbo',
#  '7ic6oOHobWw',
#  'DzuU_3lYQ8c',
#  'ryBA3kVJdx8',
#  'zwtfDT4fZ5o',
#  '479L5HanGEM',
#  'H-lnbvd1UV0',
#  'r2kKsjZPrVI',
#  'uai9Dt595mc',
#  'COI2h-61mME',
#  'o6eZwr3S5FY',
#  'Jh72phku9Zg',
#  'vw83vmoFTks',
#  '13XA8AyslpU',
#  'cYMeZs_EcqE',
#  'R-6DorkdP28',
#  '051CBvanVwU',
#  'W31qwhIbQf4',
#  'HnpMTINOBHo',
#  'EPr1CQuQpYA',
#  'tfepSyCQsEY',
#  'IUjSJk45hd4',
#  'o-TMOeCDeus',
#  'y1Pm2diAD34',
#  'QW2A-cbMjLc',
#  'PA80BSo8XQQ',
#  'cTQbBrwS0vg',
#  'dYqtgpBg1ag',
#  'iVZ-lYOJEGM',
#  'Sx994H3YEKQ',
#  'GLv6fIAFy78',
#  '8T3Y9A7Xo-s',
#  '_zhADvmUJe0',
#  'tfLd329ovRI',
#  'eGUG2icJS2w',
#  'pcu8HM7pplQ',
#  'Wqp5G8h-V9Q',
#  'sfju7EAukEs',
#  '5HTK6XnX-ns',
#  'TBE12bdWmQo',
#  'CISbbt1x2dc',
#  'Il-Vz6X2ygg',
#  'Bj3glah53dk',
#  'ENrjn-lD1e8',
#  '9JBu8s-3fCw',
#  'hrOlVPB18Uc',
#  'IG5AnNgFuAg',
#  'coK4FRASTcA',
#  'YJed3_p1b5g',
#  'laisVDBJ204',
#  '6MPNncUIyfI',
#  'CPVq18rRrEs',
#  'Dx7uCfp0qMs',
#  'aUZt-bY_0fo',
#  'mOXsdnuH2Hg',
#  'QfSGu5tL1iE',
#  'KQAVojtu14o',
#  'ZXgOXuhXtuI',
#  'W-LEXt-37Oo',
#  'umIAoY1Ox64',
#  'UKDaOtCvsTU',
#  'Cf4uQg03jYg',
#  'b7Fv3vQZvNw',
#  'ScG4Lipxark',
#  '4UJM4RFQjpU',
#  'BmDOcDkAedU',
#  'r49Gsz-lklE',
#  'wYGBix_SCZA',
#  'vSWjn-3JWQs',
#  '0viTGi0xBq8',
#  '6sWGjeGRafc',
#  'QnEH1ntbWSo',
#  '6ovC14YoLGM',
#  'TyAmoIeaN9E',
#  '2yluL1DZ70U',
#  'QJ9zfgHmA90',
#  'geVg2G6sOzk',
#  '3QGEOCm6UQs',
#  'e8z9G2IQMO0',
#  'LiP7zpryGac',
#  'MR4eRqcX4mE',
#  'sh7jXV3nwUo',
#  'ssCsEEKuN4I',
#  '2DqUhTpgShQ',
#  'EKIEu7CO078',
#  '5W9-MJXvtFI',
#  'hGtrTjeENf4',
#  'DPh3mj4uvU4',
#  'cTRXYlgcBFQ',
#  'L6by13GyZtc',
#  '_nT2WXzXfGA',
#  'fnHEDbFsZEE',
#  '6z0ZQ6Qcuns',
#  '3KOLG472t8c',
#  'i9IjiW5pULc',
#  'Dj4rGHzc-3A',
#  'otu95zL7S3k',
#  'O3jMpgA5Ww4',
#  'zXlQqtTrscU',
#  'Mj8_buWV2Cc',
#  'fuPMxdZOcdA',
#  'ColmyavhSBo',
#  'Y6sGTmLRcps',
#  'lcvxLBV-UQE',
#  '8tiQuiCdbkM',
#  'wYThZL2aMH8',
#  'WpeN2FDbIGM',
#  'K_jUpdVnYKw',
#  'tWCjhj035WY',
#  'j6iFQTZPNRA',
#  'vt2tcaeQXI0',
#  'KjiizZng_Y0',
#  '9qHE5qmrGiY',
#  'c5XzDqkv0cE',
#  'tZ5qIpJHeNU',
#  '5Fk_yU1O6w8',
#  'FIJMVPpXnDo',
#  'gwFWB7gM7-U',
#  '5o08sS5kPyk',
#  'd_A8DVEOaXw',
#  'phuXdlx8CL0',
#  'B-aJEomVH0A',
#  'CIBjX2pXQqM',
#  'wSA_6rzzvwU',
#  'dUCIkax4jdM',
#  'xIWxahsbkXE',
#  'Rlc2FrIC7Q0',
#  'QBolIeBynMQ',
#  'WN2DRp0_EIY',
#  'ETR_EIFUtAE',
#  'jJ3pxNET3gY',
#  'B8nE1LZOvH8',
#  'xnkQUgamT_k',
#  '6hpGGFALZkU',
#  '3al42ONZhVA',
#  'IiEkjYwg1NE',
#  'iX3ls-ZJcRI',
#  '2jdIRP2ftNs',
#  'YJYN1fy8OQc',
#  '4Ek6bRt-MEI',
#  'O9AgYEYk0zo',
#  'JTBqYKvy0CU',
#  'unbXcnXfSYk',
#  'KDgk-pL5yIo',
#  'Y_Q8lzDBWI8',
#  'GWReAOm3yYU',
#  '8P8g_Mt6QcU',
#  'yP6K7lKMIQE',
#  '_XugW-yg2XI',
#  '8bzjA0xhW24',
#  'DXswo-X1IuM',
#  'YIWMQymSWKY',
#  'D1DwRI9r9kY',
#  'CRGBGej0O34',
#  'gVzQuRrD4xw',
#  '1OMIORV7OH0',
#  '-koqQYQwrqA',
#  'VsIrMk0PiuE',
#  '3qDnfdsjG70',
#  'hsbhN7i7H8E',
#  'pSUNHbkN2Eo',
#  'hZwMuI843-Q',
#  'S8fGAGDvBQQ',
#  't0ka45g4Fyc',
#  'lGImgZP7L1U',
#  'YsGDLalxvfA',
#  '7qaUaplIkjQ',
#  'Qwt8soTisPA',
#  'fV727CHWJq8',
#  'OPjbilnZfX0',
#  'Wmnh4l6vMTY',
#  's3puaMD0UMM',
#  'lJ-z44KjZGc',
#  'tGdMpn8bHr0',
#  'ARzHcBieRZY',
#  '9a1f0BLTOlc',
#  'pgasbrLsrss',
#  'ZZOeyLiBKtc',
#  'pBHRnnTbzL4',
#  '9HBejYqQRn8',
#  'A_Ls1GxlSiA',
#  'uXSajNn7Jhg',
#  'gM4BnpbCGMw',
#  'U8ISnVlHV7w',
#  'dnZLGpeG5tA',
#  '2YH3u86VQFY',
#  'CGrxiAIUiNw',
#  '8A3s9WP_7l4',
#  'Dutvai4El0w',
#  'rjMbE9flUhQ',
#  'EW64ikvzHOI',
#  'dHKAzSkHhNs',
#  'LZ_R-sqksec',
#  'fSl5nOT82bM',
#  '5cOvSw0lqNQ',
#  '0eA7F63Aoh0',
#  'cseroHjs__E',
#  'uOA5h_KdjO4',
#  'Yo_mO0L8uE4',
#  '6DcltISVybI',
#  'oOw-6ZkYbv4',
#  'Uu96gewkN20',
#  '6zx-TpcdyZo',
#  'O4ypoiHZOCs',
#  'BL2ZYXLW5bU',
#  '5dL4AtHYd1w',
#  'Ncjcg97P1Tg',
#  '0vIRZZLn2a4',
#  'dPvM2n2AFAw',
#  'XPwVq56l1rk',
#  'RRcnkNgMNjM',
#  'PIxJGQpLqQM',
#  'y_xEQ7Mg1gA',
#  'wtDSi14D4yE',
#  '2FwSFYD3uis',
#  '1ZIFEASmno0',
#  'OSQXo3DpFAg',
#  'xYdvj28s6bk',
#  '48OyyhpIGZk',
#  'F2j4jEs1zbE',
#  'J-2oYWhGCZg',
#  'TDeJ5o3ZlEQ',
#  'XiexPvNkdwg',
#  '_ZCm9upWR4k',
#  'RhXiv75DLiY',
#  'saPdNKRtTsQ',
#  'Lp14L-M2y0k',
#  'E9x6hd_Ax6Y',
#  'sqr3aQ4XcDI',
#  'JSXlT_xvLko',
#  'BvZ9FNyqr7Q']

# %%
def fetch_videos_for_playlistID(playlistId: str, maxResults: int):
  ans = []
  pageToken = ''
  while(len(ans) < maxResults):
    link = f'https://yt.lemnoslife.com/playlistItems?part=snippet&playlistId={playlistId}&maxResults={min(maxResults, maxResults - len(ans))}'
    if pageToken:
      link += f'&pageToken={pageToken}'
    r = requests.get(link)
    if r.status_code != 200 or 'items' not in json.loads(r.text).keys():
      raise Exception(f'Error while fetching videoes for playlistId: {playlistId}')
    
    json_obj = json.loads(r.text)
    
    if len(json_obj['items']) == 0:
      break

    for item in json_obj['items']:
      if 'videoId' in item['snippet']['resourceId'].keys():
        ans.append(item['snippet']['resourceId']['videoId'])

    if 'nextPageToken' in json_obj.keys():
      pageToken = json_obj['nextPageToken']
    else:
      break
  return ans

# %%
fetch_videos_for_playlistID('PL9WYcwsWaJ7owjsIjNDQwdfQ8ZBNRbsTi', 100)
# Out:
# ['OTRnnUPcZCE',
#  'imNgPIeRE5Y',
#  'dqRsO3HPpQw',
#  '1ffXBrZnbyw',
#  'flurYbLRGbc',
#  '4MyK2bL3Yvo',
#  'QiG49Cj5BFE',
#  '8uw9CGDTXAo',
#  '9YP1UmX1si4',
#  'vNh2bW4rdO0',
#  'mnupD3aQPss',
#  '4apaSV0OWNQ',
#  'mVEqRt3ctvU',
#  'WJ4eOYP_Fy8',
#  'SCGPP68PUdk',
#  'Gjoxxg0c4MA',
#  'DtkUulIWjH0',
#  'bLUDX4mPiro',
#  '-r3aclHSNsw']

# %% [markdown]
# ## Preparing CNN dataset

# %%
cnn_videos_list = fetch_videos_for_channelID('UCTOoRgpHTjAQPk6Ak70u-pA', 100)
process_video_list(cnn_videos_list, 'data/cnn10_full.json')

# %% [markdown]
# ## Preparing TED playlist dataset

# %%
cnn_videos_list = fetch_videos_for_playlistID('PLlT0ph_Ig5Rc8xVBw47aZfLsOGw-lxRWb', 125)
process_video_list(cnn_videos_list[:125], 'data/ted.json')
# Out:
# 100%|██████████| 125/125 [2:15:44<00:00, 65.15s/it]

# %% [markdown]
# ## Preparing Cooking playlist dataset

# %%
ramsay_videos_list = fetch_videos_for_playlistID('PLTzMGnJjrsSy6H8uiX3XKWtUhhj2Vilw1', 100)
process_video_list(ramsay_videos_list[:100], 'data/ramsay10.json')
# Out:
# 100%|██████████| 31/31 [18:34<00:00, 35.95s/it]

# %% [markdown]
# ## Preparing Tech Reviews playlist dataset

# %%
reviews_videos_list = fetch_videos_for_playlistID('PLBsP89CPrMeNm71T5gYC6jebm9vPbLBiP', 125)
process_video_list(reviews_videos_list[:125], 'data/reviews.json')
# Out:
#   0%|          | 0/125 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1288: UserWarning: Using `max_length`'s default (142) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# 100%|██████████| 125/125 [1:51:12<00:00, 53.38s/it]

# %% [markdown]
# ## Preapring podcasts dataset

# %%
reviews_videos_list = fetch_videos_for_playlistID('PL7MFKrRPjBsseGrwSpGX0EkFNna7EzvZi', 150)
process_video_list(reviews_videos_list[:150], 'data/podcasts.json')
# Out:
#   0%|          | 0/146 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1288: UserWarning: Using `max_length`'s default (142) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# 100%|██████████| 146/146 [1:32:48<00:00, 38.14s/it]

# %% [markdown]
# ## Collect views, likes, comments, category, tags etc for a video

# %%
import json
import requests
import os

# %%
def fetch_video_details(video_id: str):
  link = f'https://yt.lemnoslife.com/noKey/videos?part=id,statistics,snippet&id={video_id}'
  r = requests.get(link)
  if r.status_code != 200 or 'items' not in json.loads(r.text).keys():
    raise Exception(f'Error while fetching details for videoId: {video_id}')
  
  json_obj = json.loads(r.text)
  return json_obj['items'][0]

# %%
fetch_video_details('8GgaCgjAFLM')
# Out:
# {'kind': 'youtube#video',
#  'etag': 'azRfVTQMKCfKdA1fSIvH15-9fEQ',
#  'id': '8GgaCgjAFLM',
#  'snippet': {'publishedAt': '2023-03-02T01:20:33Z',
#   'channelId': 'UCTOoRgpHTjAQPk6Ak70u-pA',
#   'title': 'The Future Of Travel | March 2, 2023',
#   'description': 'Today CNN 10 is looking at the origins of the coronavirus. More than three years after the first Covid-19 case was diagnosed in the United States, the FBI and the Department of Energy now believe the virus most likely originated from a lab leak in Wuhan, China. Our team will examine this theory and look at its validity. CNN 10 is also continuing our series on the future of travel with a look at NewLab, a company out of Detroit that’s conceptualizing the future of urban mobility. All that and adorable eagles building their nest on this episode of CNN 10.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8GgaCgjAFLM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/8GgaCgjAFLM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/8GgaCgjAFLM/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/8GgaCgjAFLM/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/8GgaCgjAFLM/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'channelTitle': 'CNN 10',
#   'tags': ['cnn 10',
#    'cnn10',
#    'cnn student news',
#    'cnnstudentnews',
#    'puns',
#    'news',
#    'news in 10',
#    'channel one news',
#    'channelonenews',
#    'fridaysareawesome',
#    'fridays are awesome'],
#   'categoryId': '27',
#   'liveBroadcastContent': 'none',
#   'localized': {'title': 'The Future Of Travel | March 2, 2023',
#    'description': 'Today CNN 10 is looking at the origins of the coronavirus. More than three years after the first Covid-19 case was diagnosed in the United States, the FBI and the Department of Energy now believe the virus most likely originated from a lab leak in Wuhan, China. Our team will examine this theory and look at its validity. CNN 10 is also continuing our series on the future of travel with a look at NewLab, a company out of Detroit that’s conceptualizing the future of urban mobility. All that and adorable eagles building their nest on this episode of CNN 10.'},
#   'defaultAudioLanguage': 'en'},
#  'statistics': {'viewCount': '104381',
#   'likeCount': '1046',
#   'favoriteCount': '0',
#   'commentCount': '2699'}}

# %%
def add_video_details_to_file(filepath: str):
  f = open(filepath)
  json_obj = json.load(f)
  f.close()
  
  for i in range(len(json_obj)):
    temp = fetch_video_details(json_obj[i]['id'])
    json_obj[i]['snippet'] = temp['snippet']
    json_obj[i]['statistics'] = temp['statistics']

  
  # Serializing json
  json_str = json.dumps(json_obj, indent=4)

  with open(filepath, "w") as outfile:
      outfile.write(json_str)

# %%
dir_contents = os.listdir('data')
files = list(filter(lambda x: '.json' in x, dir_contents))
files
# Out:
# ['cnn10.json',
#  'cnn10_full.json',
#  'ramsay10.json',
#  'ted.json',
#  'reviews.json',
#  'podcasts.json']

# %%
for file in files:
  add_video_details_to_file(f'data/{file}')
